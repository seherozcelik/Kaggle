# %%
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import time
import matplotlib.pyplot as plt
import torch_xla.core.xla_model as xm

# %%
def getData(typ='train',data_folders = ['1']):
    
    if typ == 'train':
        main_folder = '/kaggle/input/vesuvius-challenge-ink-detection/train/'
        #data_folders = ['1','2','3']
    else:
        main_folder = '/kaggle/input/vesuvius-challenge-ink-detection/test/'

    ps = 256 # patch size
    hps = ps//2 #half patch size    
    
    data = []
    
    for df in data_folders:
        
        im = cv2.imread(main_folder+df+'/surface_volume/00.tif', cv2.IMREAD_GRAYSCALE)
        (h,w) = im.shape
        
        mask_name = main_folder+df+'/mask.png'    
        mask = cv2.imread(mask_name, cv2.IMREAD_GRAYSCALE)
        mask = mask/255
            
        for kh in range((h//hps)+1):

            if (kh+2)*hps > h:
                height_pixs = [h-ps,h] 
            else:
                height_pixs = [kh*hps,(kh+2)*hps]

            for kw in range((w//hps)+1):
                if (kw+2)*hps > w:
                    width_pixs = [w-ps,w]
                else:
                    width_pixs = [kw*hps,(kw+2)*hps]

                   
                if mask[height_pixs[0]:height_pixs[1],width_pixs[0]:width_pixs[1]].sum() > ps*hps:
                    if typ == 'train': 
                        data.append([df,height_pixs[0],height_pixs[1],width_pixs[0],width_pixs[1]])  
                    else:
                        data.append([height_pixs[0],height_pixs[1],width_pixs[0],width_pixs[1]])
    return data

# %%
class Loss(nn.Module):

    def __init__(self):
        super(Loss, self).__init__()

    def forward(self, pred, gold):
        device = xm.xla_device()
        
        pred = pred[0,0,:,:]
        gold = torch.FloatTensor(gold.astype(np.float32)).to(device)
        
        loss = - gold * torch.log(pred + 1e-8) - (1-gold) * torch.log((1-pred) + 1e-8)
    
        return torch.mean(loss)

# %%
class UNet(nn.Module):
    def __init__(self, in_channel, first_out_channel):
        super(UNet, self).__init__()
        foc = first_out_channel
        self.b1 = self.createBlock(in_channel, foc)
        self.maxPooling1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.b2 = self.createBlock(foc, foc*2)
        self.maxPooling2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.b3 = self.createBlock(foc*2, foc*4)
        self.maxPooling3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.b4 = self.createBlock(foc*4, foc*8)
        self.convTrans1 = nn.ConvTranspose2d(foc*8, foc*4, kernel_size=2, stride=2,bias=False)
        torch.nn.init.kaiming_uniform_(self.convTrans1.weight)
        self.b5 = self.createBlock(foc*8, foc*4)
        self.convTrans2 = nn.ConvTranspose2d(foc*4, foc*2, kernel_size=2, stride=2,bias=False)
        torch.nn.init.kaiming_uniform_(self.convTrans2.weight)
        self.b6 = self.createBlock(foc*4, foc*2)
        self.convTrans3 = nn.ConvTranspose2d(foc*2, foc, kernel_size=2, stride=2,bias=False)
        torch.nn.init.kaiming_uniform_(self.convTrans3.weight)
        self.b7 = self.createBlock(foc*2, foc)
        self.b8 = nn.Conv2d(in_channels=foc, out_channels=1, kernel_size=1,bias=False)
        torch.nn.init.kaiming_uniform_(self.b8.weight)

    def forward(self,im):
        x1 = self.b1(im) # 1,32,(H,W) 
        x = self.maxPooling1(x1) # 1,32,(1/2)*(H,W) 
        x2 = self.b2(x) # 1,64,(1/2)*(H,W)
        x = self.maxPooling2(x2) # 1,64,(1/4)*(H,W) 
        x3 = self.b3(x) # 1,128,(1/4)*(H,W)
        x = self.maxPooling3(x3) # 1,128,(1/8)*(H,W) 
        x = self.b4(x) # 1,256,(1/8)*(H,W)
        x = self.convTrans1(x) # 1,128,(1/4)*(H,W)
        x = torch.cat((x, x3), dim=1) # 1,256,(1/4)*(H,W)
        x = self.b5(x) # 1,128,(1/4)*(H,W)
        x = self.convTrans2(x) # 1,64,(1/2)*(H,W)
        x = torch.cat((x, x2), dim=1) # 1,128,(1/2)*(H,W)
        x = self.b6(x) # 1,64,(1/2)*(H,W)
        x = self.convTrans3(x) # 1,32,(H,W)
        x = torch.cat((x, x1), dim=1) # 1,64,(H,W)
        x = self.b7(x) # 1,32,(H,W)
        x = self.b8(x)  # 1,1,(H,W)
        x = torch.sigmoid(x)
        return x      

    @staticmethod
    def createBlock(in_chnl, out_chnl):
        return nn.Sequential(
            nn.Conv2d(in_channels=in_chnl, out_channels=out_chnl, kernel_size=3, padding=1,bias=False),
            #nn.Dropout(p=0.3),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=out_chnl, out_channels=out_chnl, kernel_size=3, padding=1, bias=False),
            #nn.Dropout(p=0.3),
            nn.ReLU(inplace=True)
            )

# %%
in_channel = 65
first_out_channel = 16

# %%
device = xm.xla_device()

model = UNet(in_channel,first_out_channel).to(device)

loss_func = Loss()

optimizer = optim.Adam(model.parameters(),lr=0.00001)

train_loader = data.DataLoader(getData(typ='train',data_folders = ['1']),batch_size=1, shuffle=True)

######## read images ##############
main_folder = '/kaggle/input/vesuvius-challenge-ink-detection/train/'
#data_folders = ['1','2','3']
data_folders = ['1']

images = []

for df in data_folders:
    
    image_name =main_folder+df+'/surface_volume/00.tif'
    image = np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)

    for i in range(1,65):
        n=str(i)
        if i < 10:
            n=n.zfill(2)

        image_name =main_folder+df+'/surface_volume/'+n+'.tif'
        image = np.concatenate((image,np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)))

    gold_name = main_folder+df+'/inklabels.png'    
    label = cv2.imread(gold_name, cv2.IMREAD_GRAYSCALE)
    label = label/255

    images.append([image,label])
######## end read images ##############

losses = []
l = len(train_loader)
tot_time_passed = 0

trainingLoss = np.inf
epoch = 0

while trainingLoss > 0.02:
    start_time = time.time()
    loss_sum = 0
    model.train()
    for inpt_pixs in train_loader:
        image_index = int(inpt_pixs[0][0])
        image = images[image_index-1][0]
        label = images[image_index-1][1]
        
        inpt = image[:,inpt_pixs[1].item():inpt_pixs[2].item(),inpt_pixs[3].item():inpt_pixs[4].item()]
        inpt = np.expand_dims(inpt,0)
        inpt = torch.FloatTensor(inpt.astype(np.float32))

        output = model(inpt.to(device))

        optimizer.zero_grad()
        loss = loss_func(output,label[inpt_pixs[1].item():inpt_pixs[2].item(),inpt_pixs[3].item():inpt_pixs[4].item()])

        loss_sum += loss.item()
        loss.backward()
        optimizer.step()
        xm.mark_step()

    trainingLoss = loss_sum / l    
    losses.append(trainingLoss)

    time_passed = time.time() - start_time 
    tot_time_passed = tot_time_passed + time_passed
    print('epoch: ', epoch, '- trn_loss: ', round(trainingLoss,10),'- second_passed: ', 
          round(time_passed), '-tot mins: ', round(tot_time_passed/60)) 
    epoch = epoch + 1


torch.save(model.state_dict(), '/kaggle/working/weights.pth')
# Out:
# epoch:  0 - trn_loss:  0.5113601618 - second_passed:  74 -tot mins:  1
# epoch:  1 - trn_loss:  0.4732119486 - second_passed:  54 -tot mins:  2
# epoch:  2 - trn_loss:  0.4672992626 - second_passed:  54 -tot mins:  3
# epoch:  3 - trn_loss:  0.466543526 - second_passed:  62 -tot mins:  4
# epoch:  4 - trn_loss:  0.464730171 - second_passed:  54 -tot mins:  5
# epoch:  5 - trn_loss:  0.4626146447 - second_passed:  54 -tot mins:  6
# epoch:  6 - trn_loss:  0.4619964088 - second_passed:  54 -tot mins:  7
# epoch:  7 - trn_loss:  0.461273526 - second_passed:  54 -tot mins:  8
# epoch:  8 - trn_loss:  0.4603561769 - second_passed:  54 -tot mins:  9
# epoch:  9 - trn_loss:  0.4603412243 - second_passed:  62 -tot mins:  10
# epoch:  10 - trn_loss:  0.4590896897 - second_passed:  54 -tot mins:  11
# epoch:  11 - trn_loss:  0.4589413073 - second_passed:  54 -tot mins:  11
# epoch:  12 - trn_loss:  0.4588828192 - second_passed:  54 -tot mins:  12
# epoch:  13 - trn_loss:  0.4570472102 - second_passed:  55 -tot mins:  13
# epoch:  14 - trn_loss:  0.4554516931 - second_passed:  55 -tot mins:  14
# epoch:  15 - trn_loss:  0.4561066608 - second_passed:  55 -tot mins:  15
# epoch:  16 - trn_loss:  0.4545910703 - second_passed:  54 -tot mins:  16
# epoch:  17 - trn_loss:  0.4551409916 - second_passed:  54 -tot mins:  17
# epoch:  18 - trn_loss:  0.4544123223 - second_passed:  55 -tot mins:  18
# epoch:  19 - trn_loss:  0.453714383 - second_passed:  55 -tot mins:  19
# epoch:  20 - trn_loss:  0.4529653583 - second_passed:  55 -tot mins:  20
# epoch:  21 - trn_loss:  0.4521742205 - second_passed:  54 -tot mins:  21
# epoch:  22 - trn_loss:  0.4512164239 - second_passed:  55 -tot mins:  21
# epoch:  23 - trn_loss:  0.451706519 - second_passed:  55 -tot mins:  22
# epoch:  24 - trn_loss:  0.4507981193 - second_passed:  55 -tot mins:  23
# epoch:  25 - trn_loss:  0.450538098 - second_passed:  55 -tot mins:  24
# epoch:  26 - trn_loss:  0.4488890748 - second_passed:  55 -tot mins:  25
# epoch:  27 - trn_loss:  0.4486181023 - second_passed:  55 -tot mins:  26
# epoch:  28 - trn_loss:  0.4487794193 - second_passed:  55 -tot mins:  27
# epoch:  29 - trn_loss:  0.4477726868 - second_passed:  55 -tot mins:  28
# epoch:  30 - trn_loss:  0.4475360844 - second_passed:  55 -tot mins:  29
# epoch:  31 - trn_loss:  0.4474564754 - second_passed:  55 -tot mins:  30
# epoch:  32 - trn_loss:  0.4461828536 - second_passed:  54 -tot mins:  31
# epoch:  33 - trn_loss:  0.4457204074 - second_passed:  54 -tot mins:  31
# epoch:  34 - trn_loss:  0.4438915517 - second_passed:  55 -tot mins:  32
# epoch:  35 - trn_loss:  0.4475496228 - second_passed:  54 -tot mins:  33
# epoch:  36 - trn_loss:  0.4442006993 - second_passed:  54 -tot mins:  34
# epoch:  37 - trn_loss:  0.4433510227 - second_passed:  54 -tot mins:  35
# epoch:  38 - trn_loss:  0.4434141623 - second_passed:  54 -tot mins:  36
# epoch:  39 - trn_loss:  0.4432354367 - second_passed:  54 -tot mins:  37
# epoch:  40 - trn_loss:  0.4434998538 - second_passed:  54 -tot mins:  38
# epoch:  41 - trn_loss:  0.4417781171 - second_passed:  54 -tot mins:  39
# epoch:  42 - trn_loss:  0.4418896244 - second_passed:  54 -tot mins:  40
# epoch:  43 - trn_loss:  0.4417102018 - second_passed:  55 -tot mins:  41
# epoch:  44 - trn_loss:  0.4391833529 - second_passed:  54 -tot mins:  41
# epoch:  45 - trn_loss:  0.4390153641 - second_passed:  54 -tot mins:  42
# epoch:  46 - trn_loss:  0.4385394933 - second_passed:  55 -tot mins:  43
# epoch:  47 - trn_loss:  0.4374080554 - second_passed:  55 -tot mins:  44
# epoch:  48 - trn_loss:  0.4375587339 - second_passed:  55 -tot mins:  45
# epoch:  49 - trn_loss:  0.4347769966 - second_passed:  55 -tot mins:  46
# epoch:  50 - trn_loss:  0.4343688349 - second_passed:  55 -tot mins:  47
# epoch:  51 - trn_loss:  0.4329141378 - second_passed:  54 -tot mins:  48
# epoch:  52 - trn_loss:  0.4354065447 - second_passed:  55 -tot mins:  49
# epoch:  53 - trn_loss:  0.4338470823 - second_passed:  54 -tot mins:  50
# epoch:  54 - trn_loss:  0.4306535659 - second_passed:  55 -tot mins:  51
# epoch:  55 - trn_loss:  0.4325652734 - second_passed:  55 -tot mins:  51
# epoch:  56 - trn_loss:  0.432054054 - second_passed:  54 -tot mins:  52
# epoch:  57 - trn_loss:  0.4300352528 - second_passed:  55 -tot mins:  53
# epoch:  58 - trn_loss:  0.4304923299 - second_passed:  55 -tot mins:  54
# epoch:  59 - trn_loss:  0.4310527762 - second_passed:  54 -tot mins:  55
# epoch:  60 - trn_loss:  0.429709533 - second_passed:  55 -tot mins:  56
# epoch:  61 - trn_loss:  0.4283548809 - second_passed:  55 -tot mins:  57
# epoch:  62 - trn_loss:  0.4302621423 - second_passed:  55 -tot mins:  58
# epoch:  63 - trn_loss:  0.4263033598 - second_passed:  55 -tot mins:  59
# epoch:  64 - trn_loss:  0.4269884152 - second_passed:  54 -tot mins:  60
# epoch:  65 - trn_loss:  0.4255799409 - second_passed:  55 -tot mins:  61
# epoch:  66 - trn_loss:  0.4258752012 - second_passed:  55 -tot mins:  61
# epoch:  67 - trn_loss:  0.4255152755 - second_passed:  55 -tot mins:  62
# epoch:  68 - trn_loss:  0.4263579816 - second_passed:  55 -tot mins:  63
# epoch:  69 - trn_loss:  0.4251568752 - second_passed:  55 -tot mins:  64
# epoch:  70 - trn_loss:  0.4225389369 - second_passed:  54 -tot mins:  65
# epoch:  71 - trn_loss:  0.4235698794 - second_passed:  55 -tot mins:  66
# epoch:  72 - trn_loss:  0.4239478164 - second_passed:  54 -tot mins:  67
# epoch:  73 - trn_loss:  0.4240833164 - second_passed:  54 -tot mins:  68
# epoch:  74 - trn_loss:  0.422396767 - second_passed:  54 -tot mins:  69
# epoch:  75 - trn_loss:  0.421824096 - second_passed:  54 -tot mins:  70
# epoch:  76 - trn_loss:  0.4236801513 - second_passed:  54 -tot mins:  71
# epoch:  77 - trn_loss:  0.422116568 - second_passed:  55 -tot mins:  71
# epoch:  78 - trn_loss:  0.4204476475 - second_passed:  54 -tot mins:  72
# epoch:  79 - trn_loss:  0.4217207564 - second_passed:  55 -tot mins:  73
# epoch:  80 - trn_loss:  0.4217024442 - second_passed:  55 -tot mins:  74
# epoch:  81 - trn_loss:  0.4214914362 - second_passed:  54 -tot mins:  75
# epoch:  82 - trn_loss:  0.4201583962 - second_passed:  54 -tot mins:  76
# epoch:  83 - trn_loss:  0.4185944607 - second_passed:  54 -tot mins:  77
# epoch:  84 - trn_loss:  0.4207354727 - second_passed:  54 -tot mins:  78
# epoch:  85 - trn_loss:  0.4191339576 - second_passed:  54 -tot mins:  79
# epoch:  86 - trn_loss:  0.4179681448 - second_passed:  54 -tot mins:  80
# epoch:  87 - trn_loss:  0.4205484745 - second_passed:  55 -tot mins:  81
# epoch:  88 - trn_loss:  0.4189378732 - second_passed:  55 -tot mins:  81
# epoch:  89 - trn_loss:  0.4189591147 - second_passed:  54 -tot mins:  82
# epoch:  90 - trn_loss:  0.4181816401 - second_passed:  55 -tot mins:  83
# epoch:  91 - trn_loss:  0.4185576782 - second_passed:  55 -tot mins:  84
# epoch:  92 - trn_loss:  0.4197028743 - second_passed:  54 -tot mins:  85
# epoch:  93 - trn_loss:  0.4178181644 - second_passed:  54 -tot mins:  86
# epoch:  94 - trn_loss:  0.415418658 - second_passed:  54 -tot mins:  87
# epoch:  95 - trn_loss:  0.4164272394 - second_passed:  55 -tot mins:  88
# epoch:  96 - trn_loss:  0.4145702304 - second_passed:  55 -tot mins:  89
# epoch:  97 - trn_loss:  0.4161845798 - second_passed:  55 -tot mins:  90
# epoch:  98 - trn_loss:  0.416880982 - second_passed:  55 -tot mins:  91
# epoch:  99 - trn_loss:  0.4164322163 - second_passed:  55 -tot mins:  91
# epoch:  100 - trn_loss:  0.4138212475 - second_passed:  55 -tot mins:  92
# epoch:  101 - trn_loss:  0.4146471505 - second_passed:  55 -tot mins:  93
# epoch:  102 - trn_loss:  0.4131578466 - second_passed:  55 -tot mins:  94
# epoch:  103 - trn_loss:  0.4162510269 - second_passed:  55 -tot mins:  95
# epoch:  104 - trn_loss:  0.4134101062 - second_passed:  54 -tot mins:  96
# epoch:  105 - trn_loss:  0.4127742523 - second_passed:  54 -tot mins:  97
# epoch:  106 - trn_loss:  0.414017389 - second_passed:  55 -tot mins:  98
# epoch:  107 - trn_loss:  0.4109764497 - second_passed:  54 -tot mins:  99
# epoch:  108 - trn_loss:  0.4121776169 - second_passed:  55 -tot mins:  100
# epoch:  109 - trn_loss:  0.4119321972 - second_passed:  55 -tot mins:  101
# epoch:  110 - trn_loss:  0.413199984 - second_passed:  55 -tot mins:  101
# epoch:  111 - trn_loss:  0.4110318621 - second_passed:  55 -tot mins:  102
# epoch:  112 - trn_loss:  0.4112289188 - second_passed:  55 -tot mins:  103
# epoch:  113 - trn_loss:  0.4117504403 - second_passed:  54 -tot mins:  104
# epoch:  114 - trn_loss:  0.4112837467 - second_passed:  54 -tot mins:  105
# epoch:  115 - trn_loss:  0.4098976543 - second_passed:  54 -tot mins:  106
# epoch:  116 - trn_loss:  0.4102091611 - second_passed:  55 -tot mins:  107
# epoch:  117 - trn_loss:  0.4108507972 - second_passed:  55 -tot mins:  108
# epoch:  118 - trn_loss:  0.408328723 - second_passed:  55 -tot mins:  109
# epoch:  119 - trn_loss:  0.4085067943 - second_passed:  55 -tot mins:  110
# epoch:  120 - trn_loss:  0.4089596884 - second_passed:  54 -tot mins:  111
# epoch:  121 - trn_loss:  0.4071242785 - second_passed:  55 -tot mins:  111
# epoch:  122 - trn_loss:  0.4088117103 - second_passed:  55 -tot mins:  112
# epoch:  123 - trn_loss:  0.4084398161 - second_passed:  55 -tot mins:  113
# epoch:  124 - trn_loss:  0.4083141152 - second_passed:  55 -tot mins:  114
# epoch:  125 - trn_loss:  0.4048115453 - second_passed:  55 -tot mins:  115
# epoch:  126 - trn_loss:  0.4072117346 - second_passed:  55 -tot mins:  116
# epoch:  127 - trn_loss:  0.4068971342 - second_passed:  55 -tot mins:  117
# epoch:  128 - trn_loss:  0.4068464072 - second_passed:  55 -tot mins:  118
# epoch:  129 - trn_loss:  0.4062869044 - second_passed:  55 -tot mins:  119
# epoch:  130 - trn_loss:  0.4055670198 - second_passed:  55 -tot mins:  120
# epoch:  131 - trn_loss:  0.4081135604 - second_passed:  54 -tot mins:  121
# epoch:  132 - trn_loss:  0.4045549823 - second_passed:  54 -tot mins:  121
# epoch:  133 - trn_loss:  0.4049024263 - second_passed:  54 -tot mins:  122
# epoch:  134 - trn_loss:  0.4036986868 - second_passed:  54 -tot mins:  123
# epoch:  135 - trn_loss:  0.4044116533 - second_passed:  54 -tot mins:  124
# epoch:  136 - trn_loss:  0.4031683433 - second_passed:  54 -tot mins:  125
# epoch:  137 - trn_loss:  0.4032294196 - second_passed:  55 -tot mins:  126
# epoch:  138 - trn_loss:  0.4060735084 - second_passed:  55 -tot mins:  127
# epoch:  139 - trn_loss:  0.402078829 - second_passed:  55 -tot mins:  128
# epoch:  140 - trn_loss:  0.4029418889 - second_passed:  55 -tot mins:  129
# epoch:  141 - trn_loss:  0.4022702761 - second_passed:  55 -tot mins:  130
# epoch:  142 - trn_loss:  0.4005890455 - second_passed:  55 -tot mins:  131
# epoch:  143 - trn_loss:  0.4018507554 - second_passed:  55 -tot mins:  131
# epoch:  144 - trn_loss:  0.3998838641 - second_passed:  55 -tot mins:  132
# epoch:  145 - trn_loss:  0.4020232455 - second_passed:  55 -tot mins:  133
# epoch:  146 - trn_loss:  0.4004897484 - second_passed:  55 -tot mins:  134
# epoch:  147 - trn_loss:  0.3981229231 - second_passed:  55 -tot mins:  135
# epoch:  148 - trn_loss:  0.3984905406 - second_passed:  55 -tot mins:  136
# epoch:  149 - trn_loss:  0.400549206 - second_passed:  54 -tot mins:  137
# epoch:  150 - trn_loss:  0.3997145459 - second_passed:  55 -tot mins:  138
# epoch:  151 - trn_loss:  0.3991482801 - second_passed:  55 -tot mins:  139
# epoch:  152 - trn_loss:  0.402414186 - second_passed:  55 -tot mins:  140
# epoch:  153 - trn_loss:  0.4006197367 - second_passed:  54 -tot mins:  141
# epoch:  154 - trn_loss:  0.4002769064 - second_passed:  55 -tot mins:  141
# epoch:  155 - trn_loss:  0.3977618161 - second_passed:  55 -tot mins:  142
# epoch:  156 - trn_loss:  0.3972103208 - second_passed:  55 -tot mins:  143
# epoch:  157 - trn_loss:  0.3968464786 - second_passed:  55 -tot mins:  144
# epoch:  158 - trn_loss:  0.3973792044 - second_passed:  55 -tot mins:  145
# epoch:  159 - trn_loss:  0.3962202199 - second_passed:  54 -tot mins:  146
# epoch:  160 - trn_loss:  0.3949478631 - second_passed:  55 -tot mins:  147
# epoch:  161 - trn_loss:  0.3948592112 - second_passed:  55 -tot mins:  148
# epoch:  162 - trn_loss:  0.394837348 - second_passed:  55 -tot mins:  149
# epoch:  163 - trn_loss:  0.3958744461 - second_passed:  54 -tot mins:  150
# epoch:  164 - trn_loss:  0.393886225 - second_passed:  55 -tot mins:  151
# epoch:  165 - trn_loss:  0.3942893616 - second_passed:  55 -tot mins:  151
# epoch:  166 - trn_loss:  0.393521867 - second_passed:  55 -tot mins:  152
# epoch:  167 - trn_loss:  0.3922416752 - second_passed:  55 -tot mins:  153
# epoch:  168 - trn_loss:  0.3923307591 - second_passed:  55 -tot mins:  154
# epoch:  169 - trn_loss:  0.3922046261 - second_passed:  55 -tot mins:  155
# epoch:  170 - trn_loss:  0.3925050935 - second_passed:  55 -tot mins:  156
# epoch:  171 - trn_loss:  0.3914191874 - second_passed:  55 -tot mins:  157
# epoch:  172 - trn_loss:  0.3908616695 - second_passed:  55 -tot mins:  158
# epoch:  173 - trn_loss:  0.3899141612 - second_passed:  55 -tot mins:  159
# epoch:  174 - trn_loss:  0.3896511195 - second_passed:  55 -tot mins:  160
# epoch:  175 - trn_loss:  0.3907786599 - second_passed:  54 -tot mins:  161
# epoch:  176 - trn_loss:  0.3898112991 - second_passed:  55 -tot mins:  161
# epoch:  177 - trn_loss:  0.3885973006 - second_passed:  55 -tot mins:  162
# epoch:  178 - trn_loss:  0.3869915389 - second_passed:  54 -tot mins:  163
# epoch:  179 - trn_loss:  0.3874818572 - second_passed:  55 -tot mins:  164
# epoch:  180 - trn_loss:  0.3872869865 - second_passed:  55 -tot mins:  165
# epoch:  181 - trn_loss:  0.3880970386 - second_passed:  55 -tot mins:  166
# epoch:  182 - trn_loss:  0.3853941797 - second_passed:  55 -tot mins:  167
# epoch:  183 - trn_loss:  0.387220981 - second_passed:  54 -tot mins:  168
# epoch:  184 - trn_loss:  0.386964668 - second_passed:  55 -tot mins:  169
# epoch:  185 - trn_loss:  0.3838819939 - second_passed:  55 -tot mins:  170
# epoch:  186 - trn_loss:  0.3844340138 - second_passed:  55 -tot mins:  171
# epoch:  187 - trn_loss:  0.386085612 - second_passed:  55 -tot mins:  171
# epoch:  188 - trn_loss:  0.3826891437 - second_passed:  55 -tot mins:  172
# epoch:  189 - trn_loss:  0.3829456159 - second_passed:  55 -tot mins:  173
# epoch:  190 - trn_loss:  0.3833608294 - second_passed:  55 -tot mins:  174
# epoch:  191 - trn_loss:  0.382436611 - second_passed:  55 -tot mins:  175
# epoch:  192 - trn_loss:  0.3833351123 - second_passed:  55 -tot mins:  176
# epoch:  193 - trn_loss:  0.3799751605 - second_passed:  55 -tot mins:  177
# epoch:  194 - trn_loss:  0.380057183 - second_passed:  55 -tot mins:  178
# epoch:  195 - trn_loss:  0.3805429305 - second_passed:  55 -tot mins:  179
# epoch:  196 - trn_loss:  0.3790345426 - second_passed:  55 -tot mins:  180
# epoch:  197 - trn_loss:  0.3778056371 - second_passed:  55 -tot mins:  181
# epoch:  198 - trn_loss:  0.3788428118 - second_passed:  55 -tot mins:  182
# epoch:  199 - trn_loss:  0.3780311026 - second_passed:  54 -tot mins:  182
# epoch:  200 - trn_loss:  0.3764463312 - second_passed:  54 -tot mins:  183
# epoch:  201 - trn_loss:  0.3781180021 - second_passed:  54 -tot mins:  184
# epoch:  202 - trn_loss:  0.3762560276 - second_passed:  55 -tot mins:  185
# epoch:  203 - trn_loss:  0.3770612254 - second_passed:  54 -tot mins:  186
# epoch:  204 - trn_loss:  0.3758862867 - second_passed:  54 -tot mins:  187
# epoch:  205 - trn_loss:  0.3764255041 - second_passed:  54 -tot mins:  188
# epoch:  206 - trn_loss:  0.3736454328 - second_passed:  55 -tot mins:  189
# epoch:  207 - trn_loss:  0.375512838 - second_passed:  55 -tot mins:  190
# epoch:  208 - trn_loss:  0.3733975254 - second_passed:  55 -tot mins:  191
# epoch:  209 - trn_loss:  0.3716402614 - second_passed:  55 -tot mins:  192
# epoch:  210 - trn_loss:  0.3726352207 - second_passed:  55 -tot mins:  192
# epoch:  211 - trn_loss:  0.3723243277 - second_passed:  55 -tot mins:  193
# epoch:  212 - trn_loss:  0.3726542893 - second_passed:  55 -tot mins:  194
# epoch:  213 - trn_loss:  0.3706192298 - second_passed:  55 -tot mins:  195
# epoch:  214 - trn_loss:  0.3693606448 - second_passed:  55 -tot mins:  196
# epoch:  215 - trn_loss:  0.3698572146 - second_passed:  55 -tot mins:  197
# epoch:  216 - trn_loss:  0.3686164979 - second_passed:  55 -tot mins:  198
# epoch:  217 - trn_loss:  0.3686885415 - second_passed:  55 -tot mins:  199
# epoch:  218 - trn_loss:  0.366622292 - second_passed:  54 -tot mins:  200
# epoch:  219 - trn_loss:  0.3677222385 - second_passed:  55 -tot mins:  201
# epoch:  220 - trn_loss:  0.3681619356 - second_passed:  55 -tot mins:  202
# epoch:  221 - trn_loss:  0.36714983 - second_passed:  54 -tot mins:  202
# epoch:  222 - trn_loss:  0.3659270199 - second_passed:  55 -tot mins:  203
# epoch:  223 - trn_loss:  0.3627602297 - second_passed:  54 -tot mins:  204
# epoch:  224 - trn_loss:  0.3645283551 - second_passed:  54 -tot mins:  205
# epoch:  225 - trn_loss:  0.3635338771 - second_passed:  55 -tot mins:  206
# epoch:  226 - trn_loss:  0.3642913539 - second_passed:  54 -tot mins:  207
# epoch:  227 - trn_loss:  0.3611102278 - second_passed:  55 -tot mins:  208
# epoch:  228 - trn_loss:  0.3605693949 - second_passed:  55 -tot mins:  209
# epoch:  229 - trn_loss:  0.3603370273 - second_passed:  55 -tot mins:  210
# epoch:  230 - trn_loss:  0.3585785817 - second_passed:  55 -tot mins:  211
# epoch:  231 - trn_loss:  0.3576687876 - second_passed:  55 -tot mins:  212
# epoch:  232 - trn_loss:  0.3578262682 - second_passed:  55 -tot mins:  212
# epoch:  233 - trn_loss:  0.3581649686 - second_passed:  55 -tot mins:  213
# epoch:  234 - trn_loss:  0.354759328 - second_passed:  55 -tot mins:  214
# epoch:  235 - trn_loss:  0.3545277769 - second_passed:  55 -tot mins:  215
# epoch:  236 - trn_loss:  0.355516567 - second_passed:  55 -tot mins:  216
# epoch:  237 - trn_loss:  0.3535042185 - second_passed:  55 -tot mins:  217
# epoch:  238 - trn_loss:  0.3524968985 - second_passed:  55 -tot mins:  218
# epoch:  239 - trn_loss:  0.3512510095 - second_passed:  55 -tot mins:  219
# epoch:  240 - trn_loss:  0.3539578777 - second_passed:  55 -tot mins:  220
# epoch:  241 - trn_loss:  0.3497855812 - second_passed:  55 -tot mins:  221
# epoch:  242 - trn_loss:  0.3515443943 - second_passed:  55 -tot mins:  222
# epoch:  243 - trn_loss:  0.3491049021 - second_passed:  55 -tot mins:  222
# epoch:  244 - trn_loss:  0.3494668882 - second_passed:  55 -tot mins:  223
# epoch:  245 - trn_loss:  0.3497903861 - second_passed:  55 -tot mins:  224
# epoch:  246 - trn_loss:  0.3464707945 - second_passed:  55 -tot mins:  225
# epoch:  247 - trn_loss:  0.3467231536 - second_passed:  55 -tot mins:  226
# epoch:  248 - trn_loss:  0.34578535 - second_passed:  55 -tot mins:  227
# epoch:  249 - trn_loss:  0.3450404607 - second_passed:  55 -tot mins:  228
# epoch:  250 - trn_loss:  0.3426015166 - second_passed:  55 -tot mins:  229
# epoch:  251 - trn_loss:  0.3444635167 - second_passed:  55 -tot mins:  230
# epoch:  252 - trn_loss:  0.3419460913 - second_passed:  54 -tot mins:  231
# epoch:  253 - trn_loss:  0.3414994295 - second_passed:  55 -tot mins:  232
# epoch:  254 - trn_loss:  0.340182536 - second_passed:  54 -tot mins:  233
# epoch:  255 - trn_loss:  0.3393532186 - second_passed:  55 -tot mins:  233
# epoch:  256 - trn_loss:  0.3359566342 - second_passed:  55 -tot mins:  234
# epoch:  257 - trn_loss:  0.338794021 - second_passed:  54 -tot mins:  235
# epoch:  258 - trn_loss:  0.3376734398 - second_passed:  55 -tot mins:  236
# epoch:  259 - trn_loss:  0.3359907773 - second_passed:  55 -tot mins:  237
# epoch:  260 - trn_loss:  0.333745356 - second_passed:  54 -tot mins:  238
# epoch:  261 - trn_loss:  0.3351682516 - second_passed:  55 -tot mins:  239
# epoch:  262 - trn_loss:  0.3323580328 - second_passed:  55 -tot mins:  240
# epoch:  263 - trn_loss:  0.3315642113 - second_passed:  55 -tot mins:  241
# epoch:  264 - trn_loss:  0.329731637 - second_passed:  55 -tot mins:  242
# epoch:  265 - trn_loss:  0.3326361872 - second_passed:  55 -tot mins:  243
# epoch:  266 - trn_loss:  0.3277545646 - second_passed:  55 -tot mins:  243
# epoch:  267 - trn_loss:  0.3285235423 - second_passed:  55 -tot mins:  244
# epoch:  268 - trn_loss:  0.3276079929 - second_passed:  55 -tot mins:  245
# epoch:  269 - trn_loss:  0.3246239074 - second_passed:  55 -tot mins:  246
# epoch:  270 - trn_loss:  0.3246879429 - second_passed:  55 -tot mins:  247
# epoch:  271 - trn_loss:  0.3253390069 - second_passed:  55 -tot mins:  248
# epoch:  272 - trn_loss:  0.3225324715 - second_passed:  55 -tot mins:  249
# epoch:  273 - trn_loss:  0.3237058373 - second_passed:  55 -tot mins:  250
# epoch:  274 - trn_loss:  0.32297817 - second_passed:  55 -tot mins:  251
# epoch:  275 - trn_loss:  0.3182228877 - second_passed:  55 -tot mins:  252
# epoch:  276 - trn_loss:  0.3185459089 - second_passed:  55 -tot mins:  253
# epoch:  277 - trn_loss:  0.3152441066 - second_passed:  55 -tot mins:  253
# epoch:  278 - trn_loss:  0.3166321164 - second_passed:  55 -tot mins:  254
# epoch:  279 - trn_loss:  0.313476422 - second_passed:  55 -tot mins:  255
# epoch:  280 - trn_loss:  0.3150866395 - second_passed:  55 -tot mins:  256
# epoch:  281 - trn_loss:  0.3114071004 - second_passed:  55 -tot mins:  257
# epoch:  282 - trn_loss:  0.3138173092 - second_passed:  55 -tot mins:  258
# epoch:  283 - trn_loss:  0.3097475418 - second_passed:  55 -tot mins:  259
# epoch:  284 - trn_loss:  0.3082094112 - second_passed:  55 -tot mins:  260
# epoch:  285 - trn_loss:  0.3077225799 - second_passed:  55 -tot mins:  261
# epoch:  286 - trn_loss:  0.307816429 - second_passed:  55 -tot mins:  262
# epoch:  287 - trn_loss:  0.3040227475 - second_passed:  55 -tot mins:  263
# epoch:  288 - trn_loss:  0.3024292726 - second_passed:  55 -tot mins:  263
# epoch:  289 - trn_loss:  0.3027480504 - second_passed:  55 -tot mins:  264
# epoch:  290 - trn_loss:  0.3013112327 - second_passed:  55 -tot mins:  265
# epoch:  291 - trn_loss:  0.2993560324 - second_passed:  55 -tot mins:  266
# epoch:  292 - trn_loss:  0.2987559657 - second_passed:  54 -tot mins:  267
# epoch:  293 - trn_loss:  0.2962194815 - second_passed:  55 -tot mins:  268
# epoch:  294 - trn_loss:  0.29752443 - second_passed:  55 -tot mins:  269
# epoch:  295 - trn_loss:  0.2926222159 - second_passed:  55 -tot mins:  270
# epoch:  296 - trn_loss:  0.2927734516 - second_passed:  54 -tot mins:  271
# epoch:  297 - trn_loss:  0.2887646727 - second_passed:  55 -tot mins:  272
# epoch:  298 - trn_loss:  0.2895076161 - second_passed:  55 -tot mins:  273
# epoch:  299 - trn_loss:  0.2867638792 - second_passed:  55 -tot mins:  274
# epoch:  300 - trn_loss:  0.2884825947 - second_passed:  55 -tot mins:  274
# epoch:  301 - trn_loss:  0.285369783 - second_passed:  54 -tot mins:  275
# epoch:  302 - trn_loss:  0.2836644311 - second_passed:  55 -tot mins:  276
# epoch:  303 - trn_loss:  0.2838718423 - second_passed:  55 -tot mins:  277
# epoch:  304 - trn_loss:  0.2799523215 - second_passed:  55 -tot mins:  278
# epoch:  305 - trn_loss:  0.2804926079 - second_passed:  55 -tot mins:  279
# epoch:  306 - trn_loss:  0.2752903356 - second_passed:  55 -tot mins:  280
# epoch:  307 - trn_loss:  0.2753978958 - second_passed:  55 -tot mins:  281
# epoch:  308 - trn_loss:  0.2728060227 - second_passed:  55 -tot mins:  282
# epoch:  309 - trn_loss:  0.2736827826 - second_passed:  55 -tot mins:  283
# epoch:  310 - trn_loss:  0.2704601801 - second_passed:  55 -tot mins:  284
# epoch:  311 - trn_loss:  0.2680267597 - second_passed:  55 -tot mins:  284
# epoch:  312 - trn_loss:  0.2658711462 - second_passed:  55 -tot mins:  285
# epoch:  313 - trn_loss:  0.2657146357 - second_passed:  55 -tot mins:  286
# epoch:  314 - trn_loss:  0.2623345932 - second_passed:  55 -tot mins:  287
# epoch:  315 - trn_loss:  0.2610186462 - second_passed:  55 -tot mins:  288
# epoch:  316 - trn_loss:  0.260694679 - second_passed:  55 -tot mins:  289
# epoch:  317 - trn_loss:  0.2560720015 - second_passed:  55 -tot mins:  290
# epoch:  318 - trn_loss:  0.2558270288 - second_passed:  55 -tot mins:  291
# epoch:  319 - trn_loss:  0.2534149962 - second_passed:  55 -tot mins:  292
# epoch:  320 - trn_loss:  0.2515236793 - second_passed:  55 -tot mins:  293
# epoch:  321 - trn_loss:  0.2512841831 - second_passed:  55 -tot mins:  294
# epoch:  322 - trn_loss:  0.2481822236 - second_passed:  55 -tot mins:  294
# epoch:  323 - trn_loss:  0.2472425971 - second_passed:  55 -tot mins:  295
# epoch:  324 - trn_loss:  0.2455878972 - second_passed:  54 -tot mins:  296
# epoch:  325 - trn_loss:  0.2444196694 - second_passed:  55 -tot mins:  297
# epoch:  326 - trn_loss:  0.2422021237 - second_passed:  54 -tot mins:  298
# epoch:  327 - trn_loss:  0.2391227779 - second_passed:  54 -tot mins:  299
# epoch:  328 - trn_loss:  0.236796734 - second_passed:  55 -tot mins:  300
# epoch:  329 - trn_loss:  0.2363524259 - second_passed:  55 -tot mins:  301
# epoch:  330 - trn_loss:  0.2316460332 - second_passed:  55 -tot mins:  302
# epoch:  331 - trn_loss:  0.2316657322 - second_passed:  55 -tot mins:  303
# epoch:  332 - trn_loss:  0.2284097497 - second_passed:  55 -tot mins:  304
# epoch:  333 - trn_loss:  0.2281474494 - second_passed:  55 -tot mins:  304
# epoch:  334 - trn_loss:  0.223667306 - second_passed:  55 -tot mins:  305
# epoch:  335 - trn_loss:  0.2233219549 - second_passed:  55 -tot mins:  306
# epoch:  336 - trn_loss:  0.2225188898 - second_passed:  55 -tot mins:  307
# epoch:  337 - trn_loss:  0.2189740285 - second_passed:  55 -tot mins:  308
# epoch:  338 - trn_loss:  0.2174332975 - second_passed:  55 -tot mins:  309
# epoch:  339 - trn_loss:  0.214745313 - second_passed:  55 -tot mins:  310
# epoch:  340 - trn_loss:  0.2126263703 - second_passed:  55 -tot mins:  311
# epoch:  341 - trn_loss:  0.2109712286 - second_passed:  55 -tot mins:  312
# epoch:  342 - trn_loss:  0.2083308055 - second_passed:  55 -tot mins:  313
# epoch:  343 - trn_loss:  0.2087101189 - second_passed:  54 -tot mins:  314
# epoch:  344 - trn_loss:  0.2045462644 - second_passed:  55 -tot mins:  314
# epoch:  345 - trn_loss:  0.2026056258 - second_passed:  55 -tot mins:  315
# epoch:  346 - trn_loss:  0.2000837759 - second_passed:  55 -tot mins:  316
# epoch:  347 - trn_loss:  0.1990017798 - second_passed:  55 -tot mins:  317
# epoch:  348 - trn_loss:  0.1962022941 - second_passed:  55 -tot mins:  318
# epoch:  349 - trn_loss:  0.1959258955 - second_passed:  55 -tot mins:  319
# epoch:  350 - trn_loss:  0.1924290938 - second_passed:  55 -tot mins:  320
# epoch:  351 - trn_loss:  0.1906116694 - second_passed:  55 -tot mins:  321
# epoch:  352 - trn_loss:  0.1883661714 - second_passed:  54 -tot mins:  322
# epoch:  353 - trn_loss:  0.1850824511 - second_passed:  55 -tot mins:  323
# epoch:  354 - trn_loss:  0.1831534601 - second_passed:  55 -tot mins:  324
# epoch:  355 - trn_loss:  0.1832273275 - second_passed:  55 -tot mins:  324
# epoch:  356 - trn_loss:  0.1772658152 - second_passed:  55 -tot mins:  325
# epoch:  357 - trn_loss:  0.1797912441 - second_passed:  55 -tot mins:  326
# epoch:  358 - trn_loss:  0.1726267064 - second_passed:  55 -tot mins:  327
# epoch:  359 - trn_loss:  0.172589638 - second_passed:  55 -tot mins:  328
# epoch:  360 - trn_loss:  0.1685014495 - second_passed:  55 -tot mins:  329
# epoch:  361 - trn_loss:  0.1677289312 - second_passed:  55 -tot mins:  330
# epoch:  362 - trn_loss:  0.1677809418 - second_passed:  55 -tot mins:  331
# epoch:  363 - trn_loss:  0.1649332763 - second_passed:  55 -tot mins:  332
# epoch:  364 - trn_loss:  0.1607868781 - second_passed:  55 -tot mins:  333
# epoch:  365 - trn_loss:  0.1597282151 - second_passed:  55 -tot mins:  334
# epoch:  366 - trn_loss:  0.1586560372 - second_passed:  55 -tot mins:  335
# epoch:  367 - trn_loss:  0.15454861 - second_passed:  55 -tot mins:  335
# epoch:  368 - trn_loss:  0.1538739596 - second_passed:  55 -tot mins:  336
# epoch:  369 - trn_loss:  0.153194665 - second_passed:  55 -tot mins:  337
# epoch:  370 - trn_loss:  0.1504112106 - second_passed:  55 -tot mins:  338
# epoch:  371 - trn_loss:  0.1454261024 - second_passed:  55 -tot mins:  339
# epoch:  372 - trn_loss:  0.1423481036 - second_passed:  55 -tot mins:  340
# epoch:  373 - trn_loss:  0.1417998885 - second_passed:  55 -tot mins:  341
# epoch:  374 - trn_loss:  0.1394150689 - second_passed:  55 -tot mins:  342
# epoch:  375 - trn_loss:  0.1370508697 - second_passed:  54 -tot mins:  343
# epoch:  376 - trn_loss:  0.1354210904 - second_passed:  54 -tot mins:  344
# epoch:  377 - trn_loss:  0.1318818664 - second_passed:  54 -tot mins:  345
# epoch:  378 - trn_loss:  0.1307188267 - second_passed:  55 -tot mins:  345
# epoch:  379 - trn_loss:  0.1308172686 - second_passed:  55 -tot mins:  346
# epoch:  380 - trn_loss:  0.126362338 - second_passed:  54 -tot mins:  347
# epoch:  381 - trn_loss:  0.1238711336 - second_passed:  55 -tot mins:  348
# epoch:  382 - trn_loss:  0.1241021473 - second_passed:  55 -tot mins:  349
# epoch:  383 - trn_loss:  0.1204799923 - second_passed:  55 -tot mins:  350
# epoch:  384 - trn_loss:  0.1202221635 - second_passed:  55 -tot mins:  351
# epoch:  385 - trn_loss:  0.1162585589 - second_passed:  54 -tot mins:  352
# epoch:  386 - trn_loss:  0.1146025509 - second_passed:  55 -tot mins:  353
# epoch:  387 - trn_loss:  0.1125382933 - second_passed:  55 -tot mins:  354
# epoch:  388 - trn_loss:  0.1141261077 - second_passed:  55 -tot mins:  355
# epoch:  389 - trn_loss:  0.1091378481 - second_passed:  55 -tot mins:  355
# epoch:  390 - trn_loss:  0.1079916681 - second_passed:  55 -tot mins:  356
# epoch:  391 - trn_loss:  0.1065955879 - second_passed:  55 -tot mins:  357
# epoch:  392 - trn_loss:  0.1043956426 - second_passed:  55 -tot mins:  358
# epoch:  393 - trn_loss:  0.1005192251 - second_passed:  55 -tot mins:  359
# epoch:  394 - trn_loss:  0.1091333505 - second_passed:  55 -tot mins:  360
# epoch:  395 - trn_loss:  0.0969650637 - second_passed:  55 -tot mins:  361
# epoch:  396 - trn_loss:  0.0965119517 - second_passed:  55 -tot mins:  362
# epoch:  397 - trn_loss:  0.0952199624 - second_passed:  54 -tot mins:  363
# epoch:  398 - trn_loss:  0.0924838878 - second_passed:  54 -tot mins:  364
# epoch:  399 - trn_loss:  0.0911517766 - second_passed:  55 -tot mins:  365
# epoch:  400 - trn_loss:  0.0897930388 - second_passed:  55 -tot mins:  365
# epoch:  401 - trn_loss:  0.0877759549 - second_passed:  55 -tot mins:  366
# epoch:  402 - trn_loss:  0.0879595572 - second_passed:  55 -tot mins:  367
# epoch:  403 - trn_loss:  0.0855892489 - second_passed:  55 -tot mins:  368
# epoch:  404 - trn_loss:  0.0830396298 - second_passed:  55 -tot mins:  369
# epoch:  405 - trn_loss:  0.0817896671 - second_passed:  55 -tot mins:  370
# epoch:  406 - trn_loss:  0.079620355 - second_passed:  55 -tot mins:  371
# epoch:  407 - trn_loss:  0.0766258181 - second_passed:  55 -tot mins:  372
# epoch:  408 - trn_loss:  0.0790481249 - second_passed:  55 -tot mins:  373
# epoch:  409 - trn_loss:  0.0773962344 - second_passed:  55 -tot mins:  374
# epoch:  410 - trn_loss:  0.0759551843 - second_passed:  55 -tot mins:  375
# epoch:  411 - trn_loss:  0.0740236365 - second_passed:  55 -tot mins:  375
# epoch:  412 - trn_loss:  0.0738127075 - second_passed:  55 -tot mins:  376
# epoch:  413 - trn_loss:  0.0708550032 - second_passed:  55 -tot mins:  377
# epoch:  414 - trn_loss:  0.0690921886 - second_passed:  55 -tot mins:  378
# epoch:  415 - trn_loss:  0.0705545802 - second_passed:  55 -tot mins:  379
# epoch:  416 - trn_loss:  0.065389441 - second_passed:  55 -tot mins:  380
# epoch:  417 - trn_loss:  0.0654942151 - second_passed:  55 -tot mins:  381
# epoch:  418 - trn_loss:  0.0688486888 - second_passed:  55 -tot mins:  382
# epoch:  419 - trn_loss:  0.066746062 - second_passed:  55 -tot mins:  383
# epoch:  420 - trn_loss:  0.0647589566 - second_passed:  55 -tot mins:  384
# epoch:  421 - trn_loss:  0.0643535645 - second_passed:  55 -tot mins:  385
# epoch:  422 - trn_loss:  0.0594811899 - second_passed:  55 -tot mins:  386
# epoch:  423 - trn_loss:  0.0582917494 - second_passed:  55 -tot mins:  386
# epoch:  424 - trn_loss:  0.0590609119 - second_passed:  55 -tot mins:  387
# epoch:  425 - trn_loss:  0.0578321464 - second_passed:  55 -tot mins:  388
# epoch:  426 - trn_loss:  0.0567891415 - second_passed:  55 -tot mins:  389
# epoch:  427 - trn_loss:  0.0559582496 - second_passed:  55 -tot mins:  390
# epoch:  428 - trn_loss:  0.0554402534 - second_passed:  55 -tot mins:  391
# epoch:  429 - trn_loss:  0.0527605471 - second_passed:  55 -tot mins:  392
# epoch:  430 - trn_loss:  0.0511642651 - second_passed:  54 -tot mins:  393
# epoch:  431 - trn_loss:  0.0541655461 - second_passed:  55 -tot mins:  394
# epoch:  432 - trn_loss:  0.0498976839 - second_passed:  55 -tot mins:  395
# epoch:  433 - trn_loss:  0.0501514474 - second_passed:  55 -tot mins:  396
# epoch:  434 - trn_loss:  0.0484162336 - second_passed:  55 -tot mins:  396
# epoch:  435 - trn_loss:  0.0499386864 - second_passed:  55 -tot mins:  397
# epoch:  436 - trn_loss:  0.0462144258 - second_passed:  55 -tot mins:  398
# epoch:  437 - trn_loss:  0.0481447298 - second_passed:  55 -tot mins:  399
# epoch:  438 - trn_loss:  0.0459476714 - second_passed:  55 -tot mins:  400
# epoch:  439 - trn_loss:  0.0453259002 - second_passed:  55 -tot mins:  401
# epoch:  440 - trn_loss:  0.0464521719 - second_passed:  55 -tot mins:  402
# epoch:  441 - trn_loss:  0.0424247279 - second_passed:  55 -tot mins:  403
# epoch:  442 - trn_loss:  0.0447872932 - second_passed:  55 -tot mins:  404
# epoch:  443 - trn_loss:  0.0427229189 - second_passed:  55 -tot mins:  405
# epoch:  444 - trn_loss:  0.0459548614 - second_passed:  55 -tot mins:  406
# epoch:  445 - trn_loss:  0.0446063693 - second_passed:  55 -tot mins:  406
# epoch:  446 - trn_loss:  0.0388792698 - second_passed:  55 -tot mins:  407
# epoch:  447 - trn_loss:  0.040123022 - second_passed:  55 -tot mins:  408
# epoch:  448 - trn_loss:  0.0459036858 - second_passed:  55 -tot mins:  409
# epoch:  449 - trn_loss:  0.0424465188 - second_passed:  55 -tot mins:  410
# epoch:  450 - trn_loss:  0.0361787693 - second_passed:  55 -tot mins:  411
# epoch:  451 - trn_loss:  0.0387159991 - second_passed:  55 -tot mins:  412
# epoch:  452 - trn_loss:  0.0411226098 - second_passed:  55 -tot mins:  413
# epoch:  453 - trn_loss:  0.0416423055 - second_passed:  55 -tot mins:  414
# epoch:  454 - trn_loss:  0.0334686868 - second_passed:  55 -tot mins:  415
# epoch:  455 - trn_loss:  0.039783195 - second_passed:  55 -tot mins:  416
# epoch:  456 - trn_loss:  0.0395679671 - second_passed:  54 -tot mins:  416
# epoch:  457 - trn_loss:  0.0359213846 - second_passed:  54 -tot mins:  417
# epoch:  458 - trn_loss:  0.0349026281 - second_passed:  55 -tot mins:  418
# epoch:  459 - trn_loss:  0.0355970649 - second_passed:  54 -tot mins:  419
# epoch:  460 - trn_loss:  0.0399026976 - second_passed:  55 -tot mins:  420
# epoch:  461 - trn_loss:  0.0320801573 - second_passed:  55 -tot mins:  421
# epoch:  462 - trn_loss:  0.0382851916 - second_passed:  55 -tot mins:  422
# epoch:  463 - trn_loss:  0.0327879535 - second_passed:  55 -tot mins:  423
# epoch:  464 - trn_loss:  0.0340773284 - second_passed:  55 -tot mins:  424
# epoch:  465 - trn_loss:  0.0310483995 - second_passed:  55 -tot mins:  425
# epoch:  466 - trn_loss:  0.0354419334 - second_passed:  54 -tot mins:  426
# epoch:  467 - trn_loss:  0.0321622671 - second_passed:  55 -tot mins:  427
# epoch:  468 - trn_loss:  0.0321457097 - second_passed:  54 -tot mins:  427
# epoch:  469 - trn_loss:  0.0291381318 - second_passed:  55 -tot mins:  428
# epoch:  470 - trn_loss:  0.0333476013 - second_passed:  55 -tot mins:  429
# epoch:  471 - trn_loss:  0.0353644412 - second_passed:  55 -tot mins:  430
# epoch:  472 - trn_loss:  0.0291164649 - second_passed:  55 -tot mins:  431
# epoch:  473 - trn_loss:  0.0318468875 - second_passed:  55 -tot mins:  432
# epoch:  474 - trn_loss:  0.0337060793 - second_passed:  55 -tot mins:  433
# epoch:  475 - trn_loss:  0.0275684203 - second_passed:  55 -tot mins:  434
# epoch:  476 - trn_loss:  0.0330581966 - second_passed:  55 -tot mins:  435
# epoch:  477 - trn_loss:  0.0275766961 - second_passed:  54 -tot mins:  436
# epoch:  478 - trn_loss:  0.0291164535 - second_passed:  55 -tot mins:  437
# epoch:  479 - trn_loss:  0.0355916507 - second_passed:  55 -tot mins:  437
# epoch:  480 - trn_loss:  0.0278871781 - second_passed:  55 -tot mins:  438
# epoch:  481 - trn_loss:  0.0304117906 - second_passed:  55 -tot mins:  439
# epoch:  482 - trn_loss:  0.0259749428 - second_passed:  55 -tot mins:  440
# epoch:  483 - trn_loss:  0.0321714957 - second_passed:  54 -tot mins:  441
# epoch:  484 - trn_loss:  0.0292267653 - second_passed:  54 -tot mins:  442
# epoch:  485 - trn_loss:  0.0283706573 - second_passed:  55 -tot mins:  443
# epoch:  486 - trn_loss:  0.0240060495 - second_passed:  55 -tot mins:  444
# epoch:  487 - trn_loss:  0.0280151646 - second_passed:  55 -tot mins:  445
# epoch:  488 - trn_loss:  0.0318506662 - second_passed:  55 -tot mins:  446
# epoch:  489 - trn_loss:  0.0232348171 - second_passed:  55 -tot mins:  447
# epoch:  490 - trn_loss:  0.0260279662 - second_passed:  55 -tot mins:  447
# epoch:  491 - trn_loss:  0.0285421248 - second_passed:  55 -tot mins:  448
# epoch:  492 - trn_loss:  0.0315394562 - second_passed:  55 -tot mins:  449
# epoch:  493 - trn_loss:  0.0252963452 - second_passed:  55 -tot mins:  450
# epoch:  494 - trn_loss:  0.0247791475 - second_passed:  55 -tot mins:  451
# epoch:  495 - trn_loss:  0.0262507787 - second_passed:  55 -tot mins:  452
# epoch:  496 - trn_loss:  0.0251324187 - second_passed:  55 -tot mins:  453
# epoch:  497 - trn_loss:  0.0271343731 - second_passed:  55 -tot mins:  454
# epoch:  498 - trn_loss:  0.0298115882 - second_passed:  55 -tot mins:  455
# epoch:  499 - trn_loss:  0.0214886524 - second_passed:  54 -tot mins:  456
# epoch:  500 - trn_loss:  0.0273201325 - second_passed:  55 -tot mins:  457
# epoch:  501 - trn_loss:  0.0272725326 - second_passed:  55 -tot mins:  457
# epoch:  502 - trn_loss:  0.0276264397 - second_passed:  55 -tot mins:  458
# epoch:  503 - trn_loss:  0.0278048407 - second_passed:  55 -tot mins:  459
# epoch:  504 - trn_loss:  0.0232097926 - second_passed:  55 -tot mins:  460
# epoch:  505 - trn_loss:  0.0283599811 - second_passed:  55 -tot mins:  461
# epoch:  506 - trn_loss:  0.0217692608 - second_passed:  55 -tot mins:  462
# epoch:  507 - trn_loss:  0.0244982744 - second_passed:  55 -tot mins:  463
# epoch:  508 - trn_loss:  0.0344996837 - second_passed:  55 -tot mins:  464
# epoch:  509 - trn_loss:  0.021345146 - second_passed:  55 -tot mins:  465
# epoch:  510 - trn_loss:  0.0253459632 - second_passed:  55 -tot mins:  466
# epoch:  511 - trn_loss:  0.025908193 - second_passed:  55 -tot mins:  467
# epoch:  512 - trn_loss:  0.0259118058 - second_passed:  55 -tot mins:  468
# epoch:  513 - trn_loss:  0.0210663338 - second_passed:  55 -tot mins:  468
# epoch:  514 - trn_loss:  0.0279178749 - second_passed:  55 -tot mins:  469
# epoch:  515 - trn_loss:  0.0248859357 - second_passed:  55 -tot mins:  470
# epoch:  516 - trn_loss:  0.022807335 - second_passed:  54 -tot mins:  471
# epoch:  517 - trn_loss:  0.028332428 - second_passed:  55 -tot mins:  472
# epoch:  518 - trn_loss:  0.0184709718 - second_passed:  55 -tot mins:  473

# %%
fig, ax = plt.subplots()
plt.xlabel('epochs')
plt.ylabel('losses')
ax.plot(losses, label='trn')
legend = ax.legend(shadow=True, fontsize='x-large')
plt.show()

# %%
######## read images ##############
main_folder = '/kaggle/input/vesuvius-challenge-ink-detection/test/'
df = 'a'
    
image_name =main_folder+df+'/surface_volume/00.tif'
image = cv2.imread(image_name,cv2.IMREAD_GRAYSCALE)
(h,w) = image.shape
image = np.expand_dims(image, axis=0)

for i in range(1,65):
    n=str(i)
    if i < 10:
        n=n.zfill(2)

    image_name =main_folder+df+'/surface_volume/'+n+'.tif'
    image = np.concatenate((image,np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)))

######## end read images ##############
model.load_state_dict(torch.load('/kaggle/working/weights.pth'))

model.eval()
with torch.no_grad():
        
    data = getData(typ='test',data_folders=[df])
    
    predWhole_a = np.zeros((h,w), dtype=np.uint8)

    for pixs in data:
        inpt = image[:,pixs[0]:pixs[1],pixs[2]:pixs[3]]
        inpt = np.expand_dims(inpt,0)
        output = model(torch.FloatTensor(inpt).to(device))
        pre_prediction = output.detach().cpu().numpy()[0,0,:,:]
        prediction = np.uint8(np.where(pre_prediction >= 0.4,1,0))
        predWhole_a[pixs[0]:pixs[1],pixs[2]:pixs[3]] = prediction

# %%
plt.imshow(predWhole_a)

# %%
import skimage.segmentation as sg

# %%
mask_name = main_folder+df+'/mask.png'    
mask = cv2.imread(mask_name, cv2.IMREAD_GRAYSCALE)
mask = mask/255

mask_bnd = np.transpose(np.nonzero(sg.find_boundaries(mask, mode='inner').astype(np.uint8)))

# %%
#mask_bnd = []
#(r,c) = mask.shape
#for i in range(r-1):
#    for j in range(1,c-1):
#        if mask[i,j] != mask[i,j+1] or mask[i,j] != mask[i+1,j] or mask[i,j] != mask[i+1,j+1] or mask[i,j] != mask[i+1,j-1]:
#            mask_bnd.append([i,j])

# %%
for x,y in mask_bnd:
    if x-100 < 0: 
        xs = 0 
    else: 
        xs = x-100
    if x+100 > h: 
        xe = h 
    else: 
        xe = x+100
    if y-100 < 0: 
        ys = 0 
    else: 
        ys = y-100
    if y+100 > w: 
        ye = w 
    else: 
        ye = y+100
    
    predWhole_a[xs:xe,ys:ye] = 0

# %%
plt.imshow(predWhole_a)

# %%
from skimage import morphology
from scipy.ndimage import label

# %%
predWhole_a, _ = label(predWhole_a)
predWhole_a = morphology.remove_small_objects(predWhole_a, min_size=1000, connectivity=1)
predWhole_a = np.uint8(np.where(predWhole_a>0,1,0))

# %%
plt.imshow(predWhole_a)

# %%
######## read images ##############
main_folder = '/kaggle/input/vesuvius-challenge-ink-detection/test/'
df = 'b'
    
image_name =main_folder+df+'/surface_volume/00.tif'
image = cv2.imread(image_name,cv2.IMREAD_GRAYSCALE)
(h,w) = image.shape
image = np.expand_dims(image, axis=0)

for i in range(1,65):
    n=str(i)
    if i < 10:
        n=n.zfill(2)

    image_name =main_folder+df+'/surface_volume/'+n+'.tif'
    image = np.concatenate((image,np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)))

######## end read images ##############
model.load_state_dict(torch.load('/kaggle/working/weights.pth'))

model.eval()
with torch.no_grad():
        
    data = getData(typ='test',data_folders=[df])
    
    predWhole_b = np.zeros((h,w), dtype=np.uint8)

    for pixs in data:
        inpt = image[:,pixs[0]:pixs[1],pixs[2]:pixs[3]]
        inpt = np.expand_dims(inpt,0)
        output = model(torch.FloatTensor(inpt).to(device))
        pre_prediction = output.detach().cpu().numpy()[0,0,:,:]
        prediction = np.uint8(np.where(pre_prediction >= 0.4,1,0))
        predWhole_b[pixs[0]:pixs[1],pixs[2]:pixs[3]] = prediction

# %%
plt.imshow(predWhole_b)

# %%
mask_name = main_folder+df+'/mask.png'    
mask = cv2.imread(mask_name, cv2.IMREAD_GRAYSCALE)
mask = mask/255

mask_bnd = np.transpose(np.nonzero(sg.find_boundaries(mask, mode='inner').astype(np.uint8)))

# %%
#mask_bnd = []
#(r,c) = mask.shape
#for i in range(r-1):
#    for j in range(1,c-1):
#        if mask[i,j] != mask[i,j+1] or mask[i,j] != mask[i+1,j] or mask[i,j] != mask[i+1,j+1] or mask[i,j] != mask[i+1,j-1]:
#            mask_bnd.append([i,j])

# %%
for x,y in mask_bnd:
    if x-100 < 0: 
        xs = 0 
    else: 
        xs = x-100
    if x+100 > h: 
        xe = h 
    else: 
        xe = x+100
    if y-100 < 0: 
        ys = 0 
    else: 
        ys = y-100
    if y+100 > w: 
        ye = w 
    else: 
        ye = y+100
    
    predWhole_b[xs:xe,ys:ye] = 0

# %%
plt.imshow(predWhole_b)

# %%
predWhole_b, _ = label(predWhole_b)
predWhole_b = morphology.remove_small_objects(predWhole_b, min_size=1000, connectivity=1)
predWhole_b = np.uint8(np.where(predWhole_b>0,1,0))

# %%
plt.imshow(predWhole_b)

# %%
def rle(output):
    pixels = output.flatten().astype(np.uint8)
    pixels[0] = 0
    pixels[-1] = 0
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 2
    runs[1::2] = runs[1::2] - runs[:-1:2]
    return ' '.join(str(x) for x in runs)

# %%
print("Id,Predicted\na," + rle(predWhole_a) + "\nb," + rle(predWhole_b), file=open('/kaggle/working/submission.csv', 'w'))

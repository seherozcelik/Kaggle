# %%
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import time
import matplotlib.pyplot as plt

# %%
def getData(typ='train',test_data_folder = ['a']):
    
    if typ == 'train':
        main_folder = 'vesuvius-challenge-ink-detection/train/'
        data_folders = ['1','2','3']
    else:
        main_folder = 'vesuvius-challenge-ink-detection/test/'
        data_folders = test_data_folder

    ps = 256 # patch size
    hps = ps//2 #half patch size    
    
    data = []
    
    for df in data_folders:
        
        im = cv2.imread(main_folder+df+'/surface_volume/00.tif', cv2.IMREAD_GRAYSCALE)
        (h,w) = im.shape
        
        mask_name = main_folder+df+'/mask.png'    
        mask = cv2.imread(mask_name, cv2.IMREAD_GRAYSCALE)
        mask = mask/255
            
        for kh in range((h//hps)+1):

            if (kh+2)*hps > h:
                height_pixs = [h-ps,h] 
            else:
                height_pixs = [kh*hps,(kh+2)*hps]

            for kw in range((w//hps)+1):
                if (kw+2)*hps > w:
                    width_pixs = [w-ps,w]
                else:
                    width_pixs = [kw*hps,(kw+2)*hps]
    
                if mask[height_pixs[0]:height_pixs[1],width_pixs[0]:width_pixs[1]].sum() > ps*hps:
                    if typ == 'train':
                        data.append([df,height_pixs[0],height_pixs[1],width_pixs[0],width_pixs[1]])  
                    else:
                        data.append([height_pixs[0],height_pixs[1],width_pixs[0],width_pixs[1]])
    return data

# %%
class Loss(nn.Module):

    def __init__(self):
        super(Loss, self).__init__()

    def forward(self, pred, gold):
        pred = pred[0,0,:,:]
        gold = torch.FloatTensor(gold.astype(np.float32)).cuda()
        
        loss = - gold * torch.log(pred + 1e-8) - (1-gold) * torch.log((1-pred) + 1e-8)
    
        return torch.mean(loss)

# %%
class UNet(nn.Module):
    def __init__(self, in_channel, first_out_channel):
        super(UNet, self).__init__()
        foc = first_out_channel
        self.b1 = self.createBlock(in_channel, foc)
        self.maxPooling1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.b2 = self.createBlock(foc, foc*2)
        self.maxPooling2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.b3 = self.createBlock(foc*2, foc*4)
        self.maxPooling3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.b4 = self.createBlock(foc*4, foc*8)
        self.convTrans1 = nn.ConvTranspose2d(foc*8, foc*4, kernel_size=2, stride=2,bias=False)
        torch.nn.init.kaiming_uniform_(self.convTrans1.weight)
        self.b5 = self.createBlock(foc*8, foc*4)
        self.convTrans2 = nn.ConvTranspose2d(foc*4, foc*2, kernel_size=2, stride=2,bias=False)
        torch.nn.init.kaiming_uniform_(self.convTrans2.weight)
        self.b6 = self.createBlock(foc*4, foc*2)
        self.convTrans3 = nn.ConvTranspose2d(foc*2, foc, kernel_size=2, stride=2,bias=False)
        torch.nn.init.kaiming_uniform_(self.convTrans3.weight)
        self.b7 = self.createBlock(foc*2, foc)
        self.b8 = nn.Conv2d(in_channels=foc, out_channels=1, kernel_size=1,bias=False)
        torch.nn.init.kaiming_uniform_(self.b8.weight)

    def forward(self,im):
        x1 = self.b1(im) # 1,32,(H,W) 
        x = self.maxPooling1(x1) # 1,32,(1/2)*(H,W) 
        x2 = self.b2(x) # 1,64,(1/2)*(H,W)
        x = self.maxPooling2(x2) # 1,64,(1/4)*(H,W) 
        x3 = self.b3(x) # 1,128,(1/4)*(H,W)
        x = self.maxPooling3(x3) # 1,128,(1/8)*(H,W) 
        x = self.b4(x) # 1,256,(1/8)*(H,W)
        x = self.convTrans1(x) # 1,128,(1/4)*(H,W)
        x = torch.cat((x, x3), dim=1) # 1,256,(1/4)*(H,W)
        x = self.b5(x) # 1,128,(1/4)*(H,W)
        x = self.convTrans2(x) # 1,64,(1/2)*(H,W)
        x = torch.cat((x, x2), dim=1) # 1,128,(1/2)*(H,W)
        x = self.b6(x) # 1,64,(1/2)*(H,W)
        x = self.convTrans3(x) # 1,32,(H,W)
        x = torch.cat((x, x1), dim=1) # 1,64,(H,W)
        x = self.b7(x) # 1,32,(H,W)
        x = self.b8(x)  # 1,1,(H,W)
        x = torch.sigmoid(x)
        return x      

    @staticmethod
    def createBlock(in_chnl, out_chnl):
        return nn.Sequential(
            nn.Conv2d(in_channels=in_chnl, out_channels=out_chnl, kernel_size=3, padding=1,bias=False),
            #nn.Dropout(p=0.3),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=out_chnl, out_channels=out_chnl, kernel_size=3, padding=1, bias=False),
            #nn.Dropout(p=0.3),
            nn.ReLU(inplace=True)
            )

# %%
in_channel = 65
first_out_channel = 16

# %%
model = UNet(in_channel,first_out_channel).cuda()

loss_func = Loss()

optimizer = optim.Adam(model.parameters(),lr=0.00001)

train_loader = data.DataLoader(getData(),batch_size=1, shuffle=True)

######## read images ##############
main_folder = 'vesuvius-challenge-ink-detection/train/'
data_folders = ['1','2','3']

images = []

for df in data_folders:
    
    image_name =main_folder+df+'/surface_volume/00.tif'
    image = np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)

    for i in range(1,65):
        n=str(i)
        if i < 10:
            n=n.zfill(2)

        image_name =main_folder+df+'/surface_volume/'+n+'.tif'
        image = np.concatenate((image,np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)))

    gold_name = main_folder+df+'/inklabels.png'    
    label = cv2.imread(gold_name, cv2.IMREAD_GRAYSCALE)
    label = label/255

    images.append([image,label])
######## end read images ##############

losses = []
l = len(train_loader)
tot_time_passed = 0

for epoch in range(300):
    start_time = time.time()
    loss_sum = 0
    model.train()
    for inpt_pixs in train_loader:
        image_index = int(inpt_pixs[0][0])
        image = images[image_index-1][0]
        label = images[image_index-1][1]
        
        inpt = image[:,inpt_pixs[1].item():inpt_pixs[2].item(),inpt_pixs[3].item():inpt_pixs[4].item()]
        inpt = np.expand_dims(inpt,0)
        inpt = torch.FloatTensor(inpt.astype(np.float32))

        output = model(inpt.cuda())

        optimizer.zero_grad()
        loss = loss_func(output,label[inpt_pixs[1].item():inpt_pixs[2].item(),inpt_pixs[3].item():inpt_pixs[4].item()])

        loss_sum += loss.item()
        loss.backward()
        optimizer.step()

    trainingLoss = loss_sum / l    
    losses.append(trainingLoss)

    time_passed = time.time() - start_time 
    tot_time_passed = tot_time_passed + time_passed
    print('epoch: ', epoch, '- trn_loss: ', round(trainingLoss,10),'- second_passed: ', 
          round(time_passed), '-tot mins: ', round(tot_time_passed/60))    


torch.save(model.state_dict(), 'weights.pth')
# Out:
# epoch:  0 - trn_loss:  0.4541822206 - second_passed:  248 -tot mins:  4
# epoch:  1 - trn_loss:  0.4455061952 - second_passed:  249 -tot mins:  8
# epoch:  2 - trn_loss:  0.4442168677 - second_passed:  232 -tot mins:  12
# epoch:  3 - trn_loss:  0.4435767955 - second_passed:  170 -tot mins:  15
# epoch:  4 - trn_loss:  0.4426097583 - second_passed:  162 -tot mins:  18
# epoch:  5 - trn_loss:  0.4424188751 - second_passed:  161 -tot mins:  20
# epoch:  6 - trn_loss:  0.4413285145 - second_passed:  164 -tot mins:  23
# epoch:  7 - trn_loss:  0.4408472683 - second_passed:  163 -tot mins:  26
# epoch:  8 - trn_loss:  0.4396341904 - second_passed:  163 -tot mins:  29
# epoch:  9 - trn_loss:  0.4391583813 - second_passed:  162 -tot mins:  31
# epoch:  10 - trn_loss:  0.4386890858 - second_passed:  159 -tot mins:  34
# epoch:  11 - trn_loss:  0.4376551674 - second_passed:  160 -tot mins:  37
# epoch:  12 - trn_loss:  0.4364726375 - second_passed:  161 -tot mins:  39
# epoch:  13 - trn_loss:  0.4355865538 - second_passed:  160 -tot mins:  42
# epoch:  14 - trn_loss:  0.4347685308 - second_passed:  162 -tot mins:  45
# epoch:  15 - trn_loss:  0.4341580919 - second_passed:  168 -tot mins:  47
# epoch:  16 - trn_loss:  0.4335308333 - second_passed:  164 -tot mins:  50
# epoch:  17 - trn_loss:  0.432651092 - second_passed:  161 -tot mins:  53
# epoch:  18 - trn_loss:  0.4324776318 - second_passed:  162 -tot mins:  56
# epoch:  19 - trn_loss:  0.4318174131 - second_passed:  160 -tot mins:  58
# epoch:  20 - trn_loss:  0.4316589064 - second_passed:  170 -tot mins:  61
# epoch:  21 - trn_loss:  0.4310425833 - second_passed:  166 -tot mins:  64
# epoch:  22 - trn_loss:  0.4307067173 - second_passed:  161 -tot mins:  66
# epoch:  23 - trn_loss:  0.429937107 - second_passed:  162 -tot mins:  69
# epoch:  24 - trn_loss:  0.4295542975 - second_passed:  163 -tot mins:  72
# epoch:  25 - trn_loss:  0.4289135916 - second_passed:  165 -tot mins:  75
# epoch:  26 - trn_loss:  0.428421583 - second_passed:  164 -tot mins:  77
# epoch:  27 - trn_loss:  0.4281413019 - second_passed:  170 -tot mins:  80
# epoch:  28 - trn_loss:  0.4277911048 - second_passed:  160 -tot mins:  83
# epoch:  29 - trn_loss:  0.4275943478 - second_passed:  162 -tot mins:  86
# epoch:  30 - trn_loss:  0.426365961 - second_passed:  164 -tot mins:  88
# epoch:  31 - trn_loss:  0.4268244906 - second_passed:  166 -tot mins:  91
# epoch:  32 - trn_loss:  0.4257467755 - second_passed:  161 -tot mins:  94
# epoch:  33 - trn_loss:  0.4249925188 - second_passed:  159 -tot mins:  96
# epoch:  34 - trn_loss:  0.4250957406 - second_passed:  165 -tot mins:  99
# epoch:  35 - trn_loss:  0.4240883352 - second_passed:  164 -tot mins:  102
# epoch:  36 - trn_loss:  0.4245582427 - second_passed:  161 -tot mins:  105
# epoch:  37 - trn_loss:  0.4232534692 - second_passed:  161 -tot mins:  107
# epoch:  38 - trn_loss:  0.4239561179 - second_passed:  161 -tot mins:  110
# epoch:  39 - trn_loss:  0.4222181123 - second_passed:  162 -tot mins:  113
# epoch:  40 - trn_loss:  0.4222860429 - second_passed:  164 -tot mins:  115
# epoch:  41 - trn_loss:  0.4215182164 - second_passed:  168 -tot mins:  118
# epoch:  42 - trn_loss:  0.420670849 - second_passed:  163 -tot mins:  121
# epoch:  43 - trn_loss:  0.420490008 - second_passed:  163 -tot mins:  124
# epoch:  44 - trn_loss:  0.4193760084 - second_passed:  162 -tot mins:  126
# epoch:  45 - trn_loss:  0.4193094747 - second_passed:  165 -tot mins:  129
# epoch:  46 - trn_loss:  0.4184602338 - second_passed:  163 -tot mins:  132
# epoch:  47 - trn_loss:  0.4179485908 - second_passed:  163 -tot mins:  134
# epoch:  48 - trn_loss:  0.4175354511 - second_passed:  160 -tot mins:  137
# epoch:  49 - trn_loss:  0.4168718275 - second_passed:  165 -tot mins:  140
# epoch:  50 - trn_loss:  0.4161986201 - second_passed:  165 -tot mins:  143
# epoch:  51 - trn_loss:  0.4159728582 - second_passed:  162 -tot mins:  145
# epoch:  52 - trn_loss:  0.4149458987 - second_passed:  165 -tot mins:  148
# epoch:  53 - trn_loss:  0.4141886778 - second_passed:  167 -tot mins:  151
# epoch:  54 - trn_loss:  0.4141273505 - second_passed:  162 -tot mins:  154
# epoch:  55 - trn_loss:  0.4136576364 - second_passed:  166 -tot mins:  156
# epoch:  56 - trn_loss:  0.413180904 - second_passed:  167 -tot mins:  159
# epoch:  57 - trn_loss:  0.4119826599 - second_passed:  165 -tot mins:  162
# epoch:  58 - trn_loss:  0.4117905934 - second_passed:  159 -tot mins:  165
# epoch:  59 - trn_loss:  0.4106901929 - second_passed:  166 -tot mins:  167
# epoch:  60 - trn_loss:  0.4099401463 - second_passed:  162 -tot mins:  170
# epoch:  61 - trn_loss:  0.4094781165 - second_passed:  163 -tot mins:  173
# epoch:  62 - trn_loss:  0.4088685854 - second_passed:  165 -tot mins:  175
# epoch:  63 - trn_loss:  0.4083149609 - second_passed:  166 -tot mins:  178
# epoch:  64 - trn_loss:  0.4076781711 - second_passed:  167 -tot mins:  181
# epoch:  65 - trn_loss:  0.4067720892 - second_passed:  162 -tot mins:  184
# epoch:  66 - trn_loss:  0.4067821713 - second_passed:  158 -tot mins:  186
# epoch:  67 - trn_loss:  0.4055096217 - second_passed:  161 -tot mins:  189
# epoch:  68 - trn_loss:  0.4052696382 - second_passed:  164 -tot mins:  192
# epoch:  69 - trn_loss:  0.4042821101 - second_passed:  163 -tot mins:  194
# epoch:  70 - trn_loss:  0.403831053 - second_passed:  163 -tot mins:  197
# epoch:  71 - trn_loss:  0.4032274862 - second_passed:  160 -tot mins:  200
# epoch:  72 - trn_loss:  0.4026636343 - second_passed:  165 -tot mins:  203
# epoch:  73 - trn_loss:  0.4026662923 - second_passed:  163 -tot mins:  205
# epoch:  74 - trn_loss:  0.4018191196 - second_passed:  167 -tot mins:  208
# epoch:  75 - trn_loss:  0.400731674 - second_passed:  160 -tot mins:  211
# epoch:  76 - trn_loss:  0.4001080188 - second_passed:  162 -tot mins:  213
# epoch:  77 - trn_loss:  0.3995048299 - second_passed:  161 -tot mins:  216
# epoch:  78 - trn_loss:  0.398602742 - second_passed:  164 -tot mins:  219
# epoch:  79 - trn_loss:  0.3981820149 - second_passed:  166 -tot mins:  222
# epoch:  80 - trn_loss:  0.3974099056 - second_passed:  163 -tot mins:  224
# epoch:  81 - trn_loss:  0.3973439687 - second_passed:  156 -tot mins:  227
# epoch:  82 - trn_loss:  0.3966850319 - second_passed:  154 -tot mins:  230
# epoch:  83 - trn_loss:  0.3955902073 - second_passed:  159 -tot mins:  232
# epoch:  84 - trn_loss:  0.3953929996 - second_passed:  156 -tot mins:  235
# epoch:  85 - trn_loss:  0.3940829855 - second_passed:  159 -tot mins:  237
# epoch:  86 - trn_loss:  0.3934647312 - second_passed:  156 -tot mins:  240
# epoch:  87 - trn_loss:  0.3927045453 - second_passed:  156 -tot mins:  243
# epoch:  88 - trn_loss:  0.3923903442 - second_passed:  158 -tot mins:  245
# epoch:  89 - trn_loss:  0.3911873499 - second_passed:  157 -tot mins:  248
# epoch:  90 - trn_loss:  0.390418389 - second_passed:  158 -tot mins:  251
# epoch:  91 - trn_loss:  0.3897772979 - second_passed:  162 -tot mins:  253
# epoch:  92 - trn_loss:  0.3887275344 - second_passed:  161 -tot mins:  256
# epoch:  93 - trn_loss:  0.3876316856 - second_passed:  157 -tot mins:  259
# epoch:  94 - trn_loss:  0.3872206037 - second_passed:  159 -tot mins:  261
# epoch:  95 - trn_loss:  0.3860131728 - second_passed:  158 -tot mins:  264
# epoch:  96 - trn_loss:  0.3856754438 - second_passed:  157 -tot mins:  266
# epoch:  97 - trn_loss:  0.3846919763 - second_passed:  157 -tot mins:  269
# epoch:  98 - trn_loss:  0.3838679199 - second_passed:  157 -tot mins:  272
# epoch:  99 - trn_loss:  0.3823612711 - second_passed:  159 -tot mins:  274
# epoch:  100 - trn_loss:  0.3817918529 - second_passed:  156 -tot mins:  277
# epoch:  101 - trn_loss:  0.3796392681 - second_passed:  156 -tot mins:  280
# epoch:  102 - trn_loss:  0.379131867 - second_passed:  157 -tot mins:  282
# epoch:  103 - trn_loss:  0.3784431041 - second_passed:  159 -tot mins:  285
# epoch:  104 - trn_loss:  0.3771538213 - second_passed:  161 -tot mins:  287
# epoch:  105 - trn_loss:  0.3758000649 - second_passed:  160 -tot mins:  290
# epoch:  106 - trn_loss:  0.3744927597 - second_passed:  159 -tot mins:  293
# epoch:  107 - trn_loss:  0.3740237891 - second_passed:  157 -tot mins:  295
# epoch:  108 - trn_loss:  0.371828394 - second_passed:  157 -tot mins:  298
# epoch:  109 - trn_loss:  0.370842158 - second_passed:  159 -tot mins:  301
# epoch:  110 - trn_loss:  0.3702234341 - second_passed:  159 -tot mins:  303
# epoch:  111 - trn_loss:  0.3689355735 - second_passed:  157 -tot mins:  306
# epoch:  112 - trn_loss:  0.3674052824 - second_passed:  157 -tot mins:  309
# epoch:  113 - trn_loss:  0.3660012498 - second_passed:  159 -tot mins:  311
# epoch:  114 - trn_loss:  0.3645460704 - second_passed:  158 -tot mins:  314
# epoch:  115 - trn_loss:  0.3629941244 - second_passed:  156 -tot mins:  316
# epoch:  116 - trn_loss:  0.3617652288 - second_passed:  158 -tot mins:  319
# epoch:  117 - trn_loss:  0.3604616468 - second_passed:  154 -tot mins:  322
# epoch:  118 - trn_loss:  0.3582318774 - second_passed:  155 -tot mins:  324
# epoch:  119 - trn_loss:  0.3560206195 - second_passed:  159 -tot mins:  327
# epoch:  120 - trn_loss:  0.3547188259 - second_passed:  154 -tot mins:  329
# epoch:  121 - trn_loss:  0.35312907 - second_passed:  158 -tot mins:  332
# epoch:  122 - trn_loss:  0.35079159 - second_passed:  160 -tot mins:  335
# epoch:  123 - trn_loss:  0.3485646879 - second_passed:  157 -tot mins:  337
# epoch:  124 - trn_loss:  0.3461480594 - second_passed:  156 -tot mins:  340
# epoch:  125 - trn_loss:  0.3433738955 - second_passed:  157 -tot mins:  343
# epoch:  126 - trn_loss:  0.3428408262 - second_passed:  157 -tot mins:  345
# epoch:  127 - trn_loss:  0.3400651701 - second_passed:  157 -tot mins:  348
# epoch:  128 - trn_loss:  0.3373453384 - second_passed:  159 -tot mins:  350
# epoch:  129 - trn_loss:  0.3354049002 - second_passed:  162 -tot mins:  353
# epoch:  130 - trn_loss:  0.3321247434 - second_passed:  160 -tot mins:  356
# epoch:  131 - trn_loss:  0.3304832784 - second_passed:  158 -tot mins:  358
# epoch:  132 - trn_loss:  0.3271638685 - second_passed:  156 -tot mins:  361
# epoch:  133 - trn_loss:  0.3248325614 - second_passed:  156 -tot mins:  364
# epoch:  134 - trn_loss:  0.3220191864 - second_passed:  159 -tot mins:  366
# epoch:  135 - trn_loss:  0.3199542479 - second_passed:  158 -tot mins:  369
# epoch:  136 - trn_loss:  0.3155074748 - second_passed:  158 -tot mins:  372
# epoch:  137 - trn_loss:  0.3131140977 - second_passed:  156 -tot mins:  374
# epoch:  138 - trn_loss:  0.3103912134 - second_passed:  156 -tot mins:  377
# epoch:  139 - trn_loss:  0.3077803201 - second_passed:  160 -tot mins:  379
# epoch:  140 - trn_loss:  0.3040549014 - second_passed:  157 -tot mins:  382
# epoch:  141 - trn_loss:  0.3002952003 - second_passed:  156 -tot mins:  385
# epoch:  142 - trn_loss:  0.2981904234 - second_passed:  156 -tot mins:  387
# epoch:  143 - trn_loss:  0.2945253998 - second_passed:  156 -tot mins:  390
# epoch:  144 - trn_loss:  0.2913197174 - second_passed:  160 -tot mins:  393
# epoch:  145 - trn_loss:  0.2885811127 - second_passed:  157 -tot mins:  395
# epoch:  146 - trn_loss:  0.2847381974 - second_passed:  157 -tot mins:  398
# epoch:  147 - trn_loss:  0.2812044509 - second_passed:  161 -tot mins:  400
# epoch:  148 - trn_loss:  0.2780559265 - second_passed:  162 -tot mins:  403
# epoch:  149 - trn_loss:  0.2741100985 - second_passed:  156 -tot mins:  406
# epoch:  150 - trn_loss:  0.2713623989 - second_passed:  158 -tot mins:  408
# epoch:  151 - trn_loss:  0.2679017836 - second_passed:  155 -tot mins:  411
# epoch:  152 - trn_loss:  0.2637406367 - second_passed:  158 -tot mins:  414
# epoch:  153 - trn_loss:  0.2603486716 - second_passed:  159 -tot mins:  416
# epoch:  154 - trn_loss:  0.2569941628 - second_passed:  155 -tot mins:  419
# epoch:  155 - trn_loss:  0.2526128406 - second_passed:  155 -tot mins:  421
# epoch:  156 - trn_loss:  0.2496258772 - second_passed:  162 -tot mins:  424
# epoch:  157 - trn_loss:  0.2455438954 - second_passed:  158 -tot mins:  427
# epoch:  158 - trn_loss:  0.2432167762 - second_passed:  156 -tot mins:  429
# epoch:  159 - trn_loss:  0.2386112397 - second_passed:  160 -tot mins:  432
# epoch:  160 - trn_loss:  0.2349016416 - second_passed:  153 -tot mins:  435
# epoch:  161 - trn_loss:  0.2318481808 - second_passed:  157 -tot mins:  437
# epoch:  162 - trn_loss:  0.2274772384 - second_passed:  156 -tot mins:  440
# epoch:  163 - trn_loss:  0.2241207708 - second_passed:  159 -tot mins:  442
# epoch:  164 - trn_loss:  0.2200362012 - second_passed:  158 -tot mins:  445
# epoch:  165 - trn_loss:  0.2166947627 - second_passed:  156 -tot mins:  448
# epoch:  166 - trn_loss:  0.2129381207 - second_passed:  155 -tot mins:  450
# epoch:  167 - trn_loss:  0.2084389068 - second_passed:  159 -tot mins:  453
# epoch:  168 - trn_loss:  0.2063388263 - second_passed:  158 -tot mins:  456
# epoch:  169 - trn_loss:  0.2031398467 - second_passed:  155 -tot mins:  458
# epoch:  170 - trn_loss:  0.1991780573 - second_passed:  158 -tot mins:  461
# epoch:  171 - trn_loss:  0.1952843427 - second_passed:  157 -tot mins:  463
# epoch:  172 - trn_loss:  0.1922649997 - second_passed:  157 -tot mins:  466
# epoch:  173 - trn_loss:  0.1893068887 - second_passed:  157 -tot mins:  469
# epoch:  174 - trn_loss:  0.1850670322 - second_passed:  156 -tot mins:  471
# epoch:  175 - trn_loss:  0.1815488333 - second_passed:  159 -tot mins:  474
# epoch:  176 - trn_loss:  0.1790404864 - second_passed:  156 -tot mins:  476
# epoch:  177 - trn_loss:  0.1754948775 - second_passed:  159 -tot mins:  479
# epoch:  178 - trn_loss:  0.1721331732 - second_passed:  154 -tot mins:  482
# epoch:  179 - trn_loss:  0.1687221964 - second_passed:  159 -tot mins:  484
# epoch:  180 - trn_loss:  0.1657498098 - second_passed:  157 -tot mins:  487
# epoch:  181 - trn_loss:  0.1629827909 - second_passed:  157 -tot mins:  490
# epoch:  182 - trn_loss:  0.1595728189 - second_passed:  163 -tot mins:  492
# epoch:  183 - trn_loss:  0.1572242012 - second_passed:  158 -tot mins:  495
# epoch:  184 - trn_loss:  0.1541132845 - second_passed:  157 -tot mins:  498
# epoch:  185 - trn_loss:  0.1507288429 - second_passed:  156 -tot mins:  500
# epoch:  186 - trn_loss:  0.1482983481 - second_passed:  158 -tot mins:  503
# epoch:  187 - trn_loss:  0.1458112392 - second_passed:  161 -tot mins:  505
# epoch:  188 - trn_loss:  0.1422704931 - second_passed:  157 -tot mins:  508
# epoch:  189 - trn_loss:  0.1400315853 - second_passed:  160 -tot mins:  511
# epoch:  190 - trn_loss:  0.1372465334 - second_passed:  155 -tot mins:  513
# epoch:  191 - trn_loss:  0.1341477451 - second_passed:  159 -tot mins:  516
# epoch:  192 - trn_loss:  0.1319560954 - second_passed:  164 -tot mins:  519
# epoch:  193 - trn_loss:  0.1290501074 - second_passed:  159 -tot mins:  521
# epoch:  194 - trn_loss:  0.1268776091 - second_passed:  159 -tot mins:  524
# epoch:  195 - trn_loss:  0.1249644372 - second_passed:  160 -tot mins:  527
# epoch:  196 - trn_loss:  0.123060443 - second_passed:  160 -tot mins:  529
# epoch:  197 - trn_loss:  0.1196569265 - second_passed:  158 -tot mins:  532
# epoch:  198 - trn_loss:  0.118008811 - second_passed:  160 -tot mins:  535
# epoch:  199 - trn_loss:  0.1155924109 - second_passed:  158 -tot mins:  537
# epoch:  200 - trn_loss:  0.113857557 - second_passed:  158 -tot mins:  540
# epoch:  201 - trn_loss:  0.1110763948 - second_passed:  156 -tot mins:  542
# epoch:  202 - trn_loss:  0.1090793615 - second_passed:  161 -tot mins:  545
# epoch:  203 - trn_loss:  0.1075334116 - second_passed:  161 -tot mins:  548
# epoch:  204 - trn_loss:  0.1049806946 - second_passed:  161 -tot mins:  551
# epoch:  205 - trn_loss:  0.1036527617 - second_passed:  166 -tot mins:  553
# epoch:  206 - trn_loss:  0.1016947202 - second_passed:  163 -tot mins:  556
# epoch:  207 - trn_loss:  0.0997438323 - second_passed:  155 -tot mins:  559
# epoch:  208 - trn_loss:  0.0981598516 - second_passed:  162 -tot mins:  561
# epoch:  209 - trn_loss:  0.0963485211 - second_passed:  159 -tot mins:  564
# epoch:  210 - trn_loss:  0.0945470328 - second_passed:  158 -tot mins:  567
# epoch:  211 - trn_loss:  0.093247141 - second_passed:  159 -tot mins:  569
# epoch:  212 - trn_loss:  0.0913792196 - second_passed:  157 -tot mins:  572
# epoch:  213 - trn_loss:  0.090027536 - second_passed:  157 -tot mins:  574
# epoch:  214 - trn_loss:  0.0882791674 - second_passed:  153 -tot mins:  577
# epoch:  215 - trn_loss:  0.0872430994 - second_passed:  158 -tot mins:  580
# epoch:  216 - trn_loss:  0.0854438651 - second_passed:  160 -tot mins:  582
# epoch:  217 - trn_loss:  0.0844573841 - second_passed:  161 -tot mins:  585
# epoch:  218 - trn_loss:  0.0825614435 - second_passed:  156 -tot mins:  588
# epoch:  219 - trn_loss:  0.0813179903 - second_passed:  157 -tot mins:  590
# epoch:  220 - trn_loss:  0.0801599462 - second_passed:  157 -tot mins:  593
# epoch:  221 - trn_loss:  0.0790772084 - second_passed:  155 -tot mins:  595
# epoch:  222 - trn_loss:  0.0773170454 - second_passed:  157 -tot mins:  598
# epoch:  223 - trn_loss:  0.0763840105 - second_passed:  160 -tot mins:  601
# epoch:  224 - trn_loss:  0.0751618455 - second_passed:  160 -tot mins:  603
# epoch:  225 - trn_loss:  0.0734668132 - second_passed:  156 -tot mins:  606
# epoch:  226 - trn_loss:  0.0724684221 - second_passed:  159 -tot mins:  609
# epoch:  227 - trn_loss:  0.0718779609 - second_passed:  157 -tot mins:  611
# epoch:  228 - trn_loss:  0.0706163863 - second_passed:  155 -tot mins:  614
# epoch:  229 - trn_loss:  0.0690706787 - second_passed:  158 -tot mins:  616
# epoch:  230 - trn_loss:  0.0689132985 - second_passed:  157 -tot mins:  619
# epoch:  231 - trn_loss:  0.0677819627 - second_passed:  156 -tot mins:  622
# epoch:  232 - trn_loss:  0.0668652762 - second_passed:  156 -tot mins:  624
# epoch:  233 - trn_loss:  0.0657902955 - second_passed:  157 -tot mins:  627
# epoch:  234 - trn_loss:  0.0644311949 - second_passed:  153 -tot mins:  629
# epoch:  235 - trn_loss:  0.0637810052 - second_passed:  160 -tot mins:  632
# epoch:  236 - trn_loss:  0.062815943 - second_passed:  156 -tot mins:  635
# epoch:  237 - trn_loss:  0.0631102953 - second_passed:  158 -tot mins:  637
# epoch:  238 - trn_loss:  0.060591055 - second_passed:  158 -tot mins:  640
# epoch:  239 - trn_loss:  0.0604767882 - second_passed:  158 -tot mins:  643
# epoch:  240 - trn_loss:  0.0587699041 - second_passed:  159 -tot mins:  645
# epoch:  241 - trn_loss:  0.0592991472 - second_passed:  157 -tot mins:  648
# epoch:  242 - trn_loss:  0.057603954 - second_passed:  159 -tot mins:  650
# epoch:  243 - trn_loss:  0.0577166016 - second_passed:  160 -tot mins:  653
# epoch:  244 - trn_loss:  0.0562817219 - second_passed:  158 -tot mins:  656
# epoch:  245 - trn_loss:  0.0553890724 - second_passed:  157 -tot mins:  658
# epoch:  246 - trn_loss:  0.0557389777 - second_passed:  158 -tot mins:  661
# epoch:  247 - trn_loss:  0.0541882973 - second_passed:  159 -tot mins:  664
# epoch:  248 - trn_loss:  0.0536764436 - second_passed:  158 -tot mins:  666
# epoch:  249 - trn_loss:  0.0528700193 - second_passed:  156 -tot mins:  669
# epoch:  250 - trn_loss:  0.0523078843 - second_passed:  158 -tot mins:  672
# epoch:  251 - trn_loss:  0.0515506139 - second_passed:  160 -tot mins:  674
# epoch:  252 - trn_loss:  0.0509695012 - second_passed:  156 -tot mins:  677
# epoch:  253 - trn_loss:  0.0507131528 - second_passed:  159 -tot mins:  679
# epoch:  254 - trn_loss:  0.051242256 - second_passed:  157 -tot mins:  682
# epoch:  255 - trn_loss:  0.0497448816 - second_passed:  155 -tot mins:  685
# epoch:  256 - trn_loss:  0.0491132846 - second_passed:  160 -tot mins:  687
# epoch:  257 - trn_loss:  0.0484284741 - second_passed:  156 -tot mins:  690
# epoch:  258 - trn_loss:  0.0485235856 - second_passed:  160 -tot mins:  693
# epoch:  259 - trn_loss:  0.0468866751 - second_passed:  156 -tot mins:  695
# epoch:  260 - trn_loss:  0.0471092497 - second_passed:  160 -tot mins:  698
# epoch:  261 - trn_loss:  0.0463282909 - second_passed:  160 -tot mins:  701
# epoch:  262 - trn_loss:  0.0460908159 - second_passed:  162 -tot mins:  703
# epoch:  263 - trn_loss:  0.0455444508 - second_passed:  159 -tot mins:  706
# epoch:  264 - trn_loss:  0.0450725182 - second_passed:  158 -tot mins:  709
# epoch:  265 - trn_loss:  0.0438430369 - second_passed:  156 -tot mins:  711
# epoch:  266 - trn_loss:  0.0441161036 - second_passed:  156 -tot mins:  714
# epoch:  267 - trn_loss:  0.0437241685 - second_passed:  157 -tot mins:  716
# epoch:  268 - trn_loss:  0.0431999135 - second_passed:  155 -tot mins:  719
# epoch:  269 - trn_loss:  0.0436334303 - second_passed:  159 -tot mins:  722
# epoch:  270 - trn_loss:  0.042403791 - second_passed:  157 -tot mins:  724
# epoch:  271 - trn_loss:  0.0420229409 - second_passed:  157 -tot mins:  727
# epoch:  272 - trn_loss:  0.0419237687 - second_passed:  155 -tot mins:  729
# epoch:  273 - trn_loss:  0.041525668 - second_passed:  157 -tot mins:  732
# epoch:  274 - trn_loss:  0.0411157019 - second_passed:  156 -tot mins:  735
# epoch:  275 - trn_loss:  0.040663461 - second_passed:  157 -tot mins:  737
# epoch:  276 - trn_loss:  0.0401712213 - second_passed:  158 -tot mins:  740
# epoch:  277 - trn_loss:  0.0399189586 - second_passed:  157 -tot mins:  742
# epoch:  278 - trn_loss:  0.03979743 - second_passed:  163 -tot mins:  745
# epoch:  279 - trn_loss:  0.0389543081 - second_passed:  158 -tot mins:  748
# epoch:  280 - trn_loss:  0.0391414404 - second_passed:  159 -tot mins:  750
# epoch:  281 - trn_loss:  0.0381372735 - second_passed:  157 -tot mins:  753
# epoch:  282 - trn_loss:  0.0387574204 - second_passed:  156 -tot mins:  756
# epoch:  283 - trn_loss:  0.0380848436 - second_passed:  159 -tot mins:  758
# epoch:  284 - trn_loss:  0.0381953726 - second_passed:  156 -tot mins:  761
# epoch:  285 - trn_loss:  0.0369396984 - second_passed:  159 -tot mins:  764
# epoch:  286 - trn_loss:  0.0370667711 - second_passed:  157 -tot mins:  766
# epoch:  287 - trn_loss:  0.0367670486 - second_passed:  156 -tot mins:  769
# epoch:  288 - trn_loss:  0.0371192194 - second_passed:  156 -tot mins:  771
# epoch:  289 - trn_loss:  0.0368550669 - second_passed:  158 -tot mins:  774
# epoch:  290 - trn_loss:  0.0358581988 - second_passed:  158 -tot mins:  777
# epoch:  291 - trn_loss:  0.0357028208 - second_passed:  161 -tot mins:  779
# epoch:  292 - trn_loss:  0.0354728666 - second_passed:  158 -tot mins:  782
# epoch:  293 - trn_loss:  0.0351295237 - second_passed:  157 -tot mins:  785
# epoch:  294 - trn_loss:  0.0356239053 - second_passed:  158 -tot mins:  787
# epoch:  295 - trn_loss:  0.0348805697 - second_passed:  155 -tot mins:  790
# epoch:  296 - trn_loss:  0.034047409 - second_passed:  159 -tot mins:  792
# epoch:  297 - trn_loss:  0.0344448695 - second_passed:  159 -tot mins:  795
# epoch:  298 - trn_loss:  0.0336697352 - second_passed:  158 -tot mins:  798
# epoch:  299 - trn_loss:  0.034171679 - second_passed:  156 -tot mins:  800

# %%
fig, ax = plt.subplots()
plt.xlabel('epochs')
plt.ylabel('losses')
ax.plot(losses, label='trn')
legend = ax.legend(shadow=True, fontsize='x-large')
plt.show()

# %%
def rle(output):
    pixels = output.flatten().astype(np.uint8)
    pixels[0] = 0
    pixels[-1] = 0
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 2
    runs[1::2] = runs[1::2] - runs[:-1:2]
    return ' '.join(str(x) for x in runs)

# %%
model = UNet(in_channel,first_out_channel).cuda()
model_name = 'weights.pth'
model.load_state_dict(torch.load(model_name))

# %%
######## read images ##############
main_folder = 'vesuvius-challenge-ink-detection/test/'
df = 'b'
    
image_name =main_folder+df+'/surface_volume/00.tif'
image = cv2.imread(image_name,cv2.IMREAD_GRAYSCALE)
(h,w) = image.shape
image = np.expand_dims(image, axis=0)

for i in range(1,65):
    n=str(i)
    if i < 10:
        n=n.zfill(2)

    image_name =main_folder+df+'/surface_volume/'+n+'.tif'
    image = np.concatenate((image,np.expand_dims(cv2.imread(image_name,cv2.IMREAD_GRAYSCALE), axis=0)))

######## end read images ##############

model.eval()
#rle_output = []
with torch.no_grad():
        
    data = getData(typ='test',test_data_folder=[df])
    
    predWhole = np.zeros((h,w), dtype=np.uint8)

    for pixs in data:
        inpt = image[:,pixs[0]:pixs[1],pixs[2]:pixs[3]]
        inpt = np.expand_dims(inpt,0)
        output = model(torch.FloatTensor(inpt).cuda())
        pre_prediction = output.detach().cpu().numpy()[0,0,:,:]
        prediction = np.uint8(np.where(pre_prediction >= 0.5,1,0))
        predWhole[pixs[0]:pixs[1],pixs[2]:pixs[3]] = prediction

#    rle_output.append(rle(predWhole))

#print("Id,Predicted\na," + rle_output[0] + "\nb," + rle_output[1], file=open('submission.csv', 'w'))

# %%
plt.imshow(predWhole)

# %%
from skimage import morphology

# %%
from scipy.ndimage import label

# %%
labeled_array, num_features = label(predWhole)

# %%
cleaned = morphology.remove_small_objects(labeled_array, min_size=25000, connectivity=1)

# %%
plt.imshow(cleaned>0)

# %%
256*128
